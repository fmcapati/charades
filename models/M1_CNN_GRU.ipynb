# %% [markdown]
# ## M1 CNN GRU

# %%
import torch, gc
gc.collect()
torch.cuda.empty_cache()
print(f"GPU free: {(torch.cuda.get_device_properties(0).total_memory - torch.cuda.memory_reserved(0))/1024**3:.2f} GiB")
# Out:
# GPU free: 10.90 GiB

# %%
import os, gc, time, csv, cv2
os.environ["KERAS_BACKEND"]              = "torch"
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"
os.environ["PYTORCH_CUDA_ALLOC_CONF"]    = "expandable_segments:True"

import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from pathlib import Path
import keras
from keras import layers, optimizers

# ── Reproducibility ───────────────────────────────────────────────────────────
SEED = 42
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ── Paths ─────────────────────────────────────────────────────────────────────
DATA_DIR   = Path("/home2/msds2026/fcapati/ml3_2026/Projects/Final_Project/data")
FRAMES_DIR = DATA_DIR / "UCF50_frames"
DATASET_DIR = DATA_DIR / "UCF50"

# ── Config ────────────────────────────────────────────────────────────────────
IMG_HEIGHT      = 64
IMG_WIDTH       = 64
SEQUENCE_LENGTH = 16
BATCH_SIZE      = 4
EPOCHS          = 20
LEARNING_RATE   = 1e-4
NUM_CLASSES     = 50

# ── Class mapping ─────────────────────────────────────────────────────────────
CLASS_NAMES_SORTED = sorted([d.name for d in DATASET_DIR.iterdir() if d.is_dir()])
class_to_idx       = {cls: idx for idx, cls in enumerate(CLASS_NAMES_SORTED)}
idx_to_class       = {idx: cls for cls, idx in class_to_idx.items()}

print(f"✅ Keras backend : {keras.backend.backend()}")
print(f"✅ Device        : {DEVICE}")
print(f"✅ Classes       : {len(class_to_idx)}")
print(f"✅ Frames dir    : {FRAMES_DIR.exists()}")
# Out:
# ✅ Keras backend : torch
# ✅ Device        : cuda
# ✅ Classes       : 50
# ✅ Frames dir    : True

# %%
class PreextractedDataset(Dataset):
    """Loads pre-extracted .npy frame arrays — fast, no video I/O during training."""
    def __init__(self, frames_dir, split, class_to_idx):
        self.samples = []
        for class_dir in sorted((Path(frames_dir) / split).iterdir()):
            if not class_dir.is_dir():
                continue
            label = class_to_idx[class_dir.name]
            for npy_path in sorted(class_dir.glob("*.npy")):
                self.samples.append((str(npy_path), label))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        npy_path, label = self.samples[idx]
        frames = np.load(npy_path)  # (16, 112, 112, 3)
        
        # Resize to target resolution if needed
        if frames.shape[1] != IMG_HEIGHT:
            frames = np.stack([
                cv2.resize(f, (IMG_WIDTH, IMG_HEIGHT)) for f in frames
            ])
        
        frames = torch.tensor(frames).permute(3, 0, 1, 2).float()
        return frames, torch.tensor(label, dtype=torch.long)


train_dataset = PreextractedDataset(FRAMES_DIR, "train", class_to_idx)
val_dataset   = PreextractedDataset(FRAMES_DIR, "val",   class_to_idx)
test_dataset  = PreextractedDataset(FRAMES_DIR, "test",  class_to_idx)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,
                          num_workers=0, pin_memory=False)
val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=0, pin_memory=False)
test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=0, pin_memory=False)

print(f"✅ Train : {len(train_dataset):,} videos → {len(train_loader)} steps/epoch")
print(f"✅ Val   : {len(val_dataset):,} videos → {len(val_loader)} steps/epoch")
print(f"✅ Test  : {len(test_dataset):,} videos → {len(test_loader)} steps/epoch")

# ── Quick shape check ─────────────────────────────────────────────────────────
sample_frames, sample_labels = next(iter(train_loader))
print(f"\nBatch frames : {sample_frames.shape}  → (B, C, T, H, W)")
print(f"Batch labels : {sample_labels.shape}  dtype={sample_labels.dtype}")
# Out:
# ✅ Train : 5,288 videos → 1322 steps/epoch
# ✅ Val   : 640 videos → 160 steps/epoch
# ✅ Test  : 698 videos → 175 steps/epoch
#
# Batch frames : torch.Size([4, 3, 16, 64, 64])  → (B, C, T, H, W)
# Batch labels : torch.Size([4])  dtype=torch.int64

# %%
def train_model_keras(model, model_name, train_loader, val_loader, epochs=EPOCHS):
    """
    Training loop for Keras (torch backend) with PyTorch DataLoader.
    Features: per-batch cache clearing, early stopping (patience=5),
    checkpointing, CSV history logging, flush=True for real-time output.
    """
    gc.collect()
    torch.cuda.empty_cache()
    print(f"GPU memory reserved: {torch.cuda.memory_reserved()/1024**3:.2f} GiB", flush=True)

    model.compile(
        optimizer = optimizers.Adam(learning_rate=LEARNING_RATE),
        loss      = "sparse_categorical_crossentropy",
        metrics   = ["accuracy"]
    )

    best_val_loss  = float("inf")
    patience_count = 0
    patience       = 5
    history        = []

    print(f"\n{'='*60}", flush=True)
    print(f"Training: {model_name}", flush=True)
    print(f"{'='*60}", flush=True)

    for epoch in range(1, epochs + 1):
        t0 = time.time()

        # ── Training ──────────────────────────────────────────────────────────
        train_losses, train_accs = [], []
        for batch_idx, (frames, labels) in enumerate(train_loader):
            frames_np = frames.permute(0, 2, 3, 4, 1).numpy()
            labels_np = labels.numpy()
            metrics   = model.train_on_batch(frames_np, labels_np)
            train_losses.append(metrics[0])
            train_accs.append(metrics[1])

            # Clear cache every 50 batches to prevent fragmentation
            if (batch_idx + 1) % 50 == 0:
                torch.cuda.empty_cache()

            if (batch_idx + 1) % 100 == 0:
                print(f"  Epoch {epoch} | Batch {batch_idx+1}/{len(train_loader)} | "
                      f"loss: {metrics[0]:.4f}  acc: {metrics[1]:.4f}", flush=True)

        # ── Validation ────────────────────────────────────────────────────────
        val_losses, val_accs = [], []
        for frames, labels in val_loader:
            frames_np = frames.permute(0, 2, 3, 4, 1).numpy()
            labels_np = labels.numpy()
            metrics   = model.test_on_batch(frames_np, labels_np)
            val_losses.append(metrics[0])
            val_accs.append(metrics[1])

        train_loss = sum(train_losses) / len(train_losses)
        train_acc  = sum(train_accs)  / len(train_accs)
        val_loss   = sum(val_losses)  / len(val_losses)
        val_acc    = sum(val_accs)    / len(val_accs)
        elapsed    = time.time() - t0

        history.append({
            "epoch": epoch, "train_loss": train_loss, "train_acc": train_acc,
            "val_loss": val_loss, "val_acc": val_acc
        })

        print(f"Epoch {epoch:02d}/{epochs} | "
              f"train_loss: {train_loss:.4f}  train_acc: {train_acc:.4f} | "
              f"val_loss: {val_loss:.4f}  val_acc: {val_acc:.4f} | "
              f"{elapsed:.1f}s", flush=True)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            model.save(f"best_{model_name}.keras")
            print(f"  💾 Saved best model (val_loss: {best_val_loss:.4f})", flush=True)
            patience_count = 0
        else:
            patience_count += 1
            print(f"  ⏳ No improvement ({patience_count}/{patience})", flush=True)
            if patience_count >= patience:
                print(f"\nEarly stopping at epoch {epoch}.", flush=True)
                break

    # Save history to CSV
    with open(f"history_{model_name}.csv", "w", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=history[0].keys())
        writer.writeheader()
        writer.writerows(history)

    print(f"\n✅ Training complete. Best val_loss: {best_val_loss:.4f}", flush=True)
    return model, history

print("✅ Training loop ready")
# Out:
# ✅ Training loop ready

# %% [markdown]
# ### Model Definition

# %%
# ── M1: CNN + GRU ────────────────────────────────────────────────────────────
inputs = keras.Input(shape=(SEQUENCE_LENGTH, IMG_HEIGHT, IMG_WIDTH, 3))

x = layers.TimeDistributed(layers.Conv2D(16, (3,3), activation="relu", padding="same"))(inputs)
x = layers.TimeDistributed(layers.MaxPooling2D((2,2)))(x)

x = layers.TimeDistributed(layers.Conv2D(32, (3,3), activation="relu", padding="same"))(x)
x = layers.TimeDistributed(layers.MaxPooling2D((2,2)))(x)

x = layers.TimeDistributed(layers.Conv2D(64, (3,3), activation="relu", padding="same"))(x)
x = layers.TimeDistributed(layers.GlobalAveragePooling2D())(x)

x = layers.GRU(128, return_sequences=False)(x)
x = layers.Dense(256, activation="relu")(x)
outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)

model = keras.Model(inputs, outputs, name="CNN_GRU")
model.summary()
# Out:
# Model: "CNN_GRU"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 16, 64, 64, 3)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 16, 64, 64, 16) │           448 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 16, 32, 32, 16) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 16, 32, 32, 32) │         4,640 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_3              │ (None, 16, 16, 16, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_4              │ (None, 16, 16, 16, 64) │        18,496 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_5              │ (None, 16, 64)         │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 128)            │        74,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 50)             │        12,850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 143,954 (562.32 KB)
#  Trainable params: 143,954 (562.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Training

# %%
model, history = train_model_keras(model, "CNN_GRU", train_loader, val_loader)
# Out:
# GPU memory reserved: 0.00 GiB
#
# ============================================================
# Training: CNN_GRU
# ============================================================
# /home/msds2026/fcapati/.conda/envs/msds2026-ml3-cnn/lib/python3.11/site-packages/keras/src/backend/torch/rnn.py:853: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1479.)
#   outputs, h_n = torch._VF.gru(
#   Epoch 1 | Batch 100/1322 | loss: 3.9133  acc: 0.0225
#   Epoch 1 | Batch 200/1322 | loss: 3.9116  acc: 0.0300
#   Epoch 1 | Batch 300/1322 | loss: 3.9109  acc: 0.0292
#   Epoch 1 | Batch 400/1322 | loss: 3.9078  acc: 0.0294
#   Epoch 1 | Batch 500/1322 | loss: 3.9058  acc: 0.0285
#   Epoch 1 | Batch 600/1322 | loss: 3.9050  acc: 0.0267
#   Epoch 1 | Batch 700/1322 | loss: 3.8987  acc: 0.0289
#   Epoch 1 | Batch 800/1322 | loss: 3.8908  acc: 0.0303
#   Epoch 1 | Batch 900/1322 | loss: 3.8774  acc: 0.0325
#   Epoch 1 | Batch 1000/1322 | loss: 3.8619  acc: 0.0330
#   Epoch 2 | Batch 100/1322 | loss: 3.7891  acc: 0.0412
#   Epoch 2 | Batch 200/1322 | loss: 3.7791  acc: 0.0416
#   Epoch 2 | Batch 300/1322 | loss: 3.7728  acc: 0.0424
#   Epoch 2 | Batch 400/1322 | loss: 3.7660  acc: 0.0426
#   Epoch 2 | Batch 500/1322 | loss: 3.7568  acc: 0.0438
#   Epoch 2 | Batch 600/1322 | loss: 3.7497  acc: 0.0439
#   Epoch 2 | Batch 700/1322 | loss: 3.7398  acc: 0.0454
#   Epoch 2 | Batch 800/1322 | loss: 3.7325  acc: 0.0472
#   Epoch 2 | Batch 900/1322 | loss: 3.7245  acc: 0.0491
#   Epoch 2 | Batch 1000/1322 | loss: 3.7148  acc: 0.0496
#   Epoch 2 | Batch 1100/1322 | loss: 3.7049  acc: 0.0512
#   Epoch 2 | Batch 1200/1322 | loss: 3.6995  acc: 0.0525
#   Epoch 2 | Batch 1300/1322 | loss: 3.6918  acc: 0.0530
#   Epoch 3 | Batch 300/1322 | loss: 3.6556  acc: 0.0609
#   Epoch 3 | Batch 400/1322 | loss: 3.6475  acc: 0.0618
#   Epoch 3 | Batch 500/1322 | loss: 3.6399  acc: 0.0634
#   Epoch 3 | Batch 600/1322 | loss: 3.6322  acc: 0.0647
#   Epoch 3 | Batch 700/1322 | loss: 3.6270  acc: 0.0662
#   Epoch 3 | Batch 800/1322 | loss: 3.6205  acc: 0.0673
#   Epoch 3 | Batch 900/1322 | loss: 3.6152  acc: 0.0687
#   Epoch 3 | Batch 1000/1322 | loss: 3.6098  acc: 0.0699
#   Epoch 3 | Batch 1100/1322 | loss: 3.6051  acc: 0.0708
#   Epoch 3 | Batch 1200/1322 | loss: 3.5990  acc: 0.0716
#   Epoch 3 | Batch 1300/1322 | loss: 3.5932  acc: 0.0723
# Epoch 03/20 | train_loss: 3.6315  train_acc: 0.0654 | val_loss: 3.5846  val_acc: 0.0749 | 329.2s
#   💾 Saved best model (val_loss: 3.5846)
#   Epoch 4 | Batch 100/1322 | loss: 3.5777  acc: 0.0761
#   Epoch 4 | Batch 200/1322 | loss: 3.5736  acc: 0.0766
#   Epoch 4 | Batch 300/1322 | loss: 3.5685  acc: 0.0780
#   Epoch 4 | Batch 400/1322 | loss: 3.5631  acc: 0.0789
#   Epoch 4 | Batch 500/1322 | loss: 3.5572  acc: 0.0796
#   Epoch 4 | Batch 600/1322 | loss: 3.5513  acc: 0.0807
#   Epoch 4 | Batch 700/1322 | loss: 3.5476  acc: 0.0810
#   Epoch 4 | Batch 800/1322 | loss: 3.5436  acc: 0.0818
#   Epoch 4 | Batch 900/1322 | loss: 3.5388  acc: 0.0828
#   Epoch 4 | Batch 1000/1322 | loss: 3.5340  acc: 0.0832
#   Epoch 4 | Batch 1100/1322 | loss: 3.5300  acc: 0.0838
#   Epoch 4 | Batch 1200/1322 | loss: 3.5258  acc: 0.0844
#   Epoch 4 | Batch 1300/1322 | loss: 3.5206  acc: 0.0861
# Epoch 04/20 | train_loss: 3.5504  train_acc: 0.0807 | val_loss: 3.5145  val_acc: 0.0879 | 309.7s
#   💾 Saved best model (val_loss: 3.5145)
#   Epoch 5 | Batch 100/1322 | loss: 3.5078  acc: 0.0886
#   Epoch 5 | Batch 200/1322 | loss: 3.5036  acc: 0.0895
#   Epoch 5 | Batch 300/1322 | loss: 3.5010  acc: 0.0896
#   Epoch 5 | Batch 400/1322 | loss: 3.4979  acc: 0.0900
#   Epoch 5 | Batch 500/1322 | loss: 3.4933  acc: 0.0908
#   Epoch 5 | Batch 600/1322 | loss: 3.4894  acc: 0.0910
#   Epoch 5 | Batch 700/1322 | loss: 3.4850  acc: 0.0917
#   Epoch 5 | Batch 800/1322 | loss: 3.4811  acc: 0.0927
#   Epoch 5 | Batch 900/1322 | loss: 3.4781  acc: 0.0931
#   Epoch 5 | Batch 1000/1322 | loss: 3.4744  acc: 0.0939
#   Epoch 5 | Batch 1100/1322 | loss: 3.4715  acc: 0.0944
#   Epoch 5 | Batch 1200/1322 | loss: 3.4686  acc: 0.0947
#   Epoch 5 | Batch 1300/1322 | loss: 3.4652  acc: 0.0955
#   Epoch 6 | Batch 400/1322 | loss: 3.4466  acc: 0.0992
#   Epoch 6 | Batch 500/1322 | loss: 3.4425  acc: 0.1000
#   Epoch 6 | Batch 600/1322 | loss: 3.4392  acc: 0.1007
#   Epoch 6 | Batch 700/1322 | loss: 3.4360  acc: 0.1014
#   Epoch 6 | Batch 800/1322 | loss: 3.4332  acc: 0.1021
#   Epoch 6 | Batch 900/1322 | loss: 3.4305  acc: 0.1028
#   Epoch 6 | Batch 1000/1322 | loss: 3.4274  acc: 0.1037
#   Epoch 6 | Batch 1100/1322 | loss: 3.4249  acc: 0.1039
#   Epoch 7 | Batch 100/1322 | loss: 3.4147  acc: 0.1058
#   Epoch 7 | Batch 200/1322 | loss: 3.4110  acc: 0.1065
#   Epoch 7 | Batch 300/1322 | loss: 3.4074  acc: 0.1071
#   Epoch 7 | Batch 400/1322 | loss: 3.4049  acc: 0.1075
#   Epoch 7 | Batch 500/1322 | loss: 3.4017  acc: 0.1081
#   Epoch 7 | Batch 600/1322 | loss: 3.3994  acc: 0.1084
#   Epoch 7 | Batch 700/1322 | loss: 3.3965  acc: 0.1089
#   Epoch 7 | Batch 800/1322 | loss: 3.3944  acc: 0.1091
#   Epoch 7 | Batch 900/1322 | loss: 3.3914  acc: 0.1097
#   Epoch 7 | Batch 1000/1322 | loss: 3.3898  acc: 0.1104
# Epoch 07/20 | train_loss: 3.3985  train_acc: 0.1087 | val_loss: 3.3796  val_acc: 0.1126 | 306.3s
#   💾 Saved best model (val_loss: 3.3796)
#   Epoch 8 | Batch 100/1322 | loss: 3.3762  acc: 0.1132
#   Epoch 8 | Batch 200/1322 | loss: 3.3743  acc: 0.1134
#   Epoch 8 | Batch 300/1322 | loss: 3.3717  acc: 0.1140
#   Epoch 8 | Batch 400/1322 | loss: 3.3692  acc: 0.1145
#   Epoch 8 | Batch 500/1322 | loss: 3.3674  acc: 0.1149
#   Epoch 8 | Batch 600/1322 | loss: 3.3649  acc: 0.1152
#   Epoch 8 | Batch 700/1322 | loss: 3.3629  acc: 0.1157
#   Epoch 8 | Batch 800/1322 | loss: 3.3606  acc: 0.1161
#   Epoch 8 | Batch 900/1322 | loss: 3.3583  acc: 0.1164
#   Epoch 8 | Batch 1000/1322 | loss: 3.3568  acc: 0.1166
#   Epoch 8 | Batch 1100/1322 | loss: 3.3543  acc: 0.1171
#   Epoch 8 | Batch 1200/1322 | loss: 3.3526  acc: 0.1173
#   Epoch 8 | Batch 1300/1322 | loss: 3.3498  acc: 0.1178
# Epoch 08/20 | train_loss: 3.3639  train_acc: 0.1154 | val_loss: 3.3473  val_acc: 0.1185 | 305.5s
#   💾 Saved best model (val_loss: 3.3473)
#   Epoch 9 | Batch 100/1322 | loss: 3.3456  acc: 0.1190
#   Epoch 9 | Batch 200/1322 | loss: 3.3432  acc: 0.1195
#   Epoch 9 | Batch 300/1322 | loss: 3.3408  acc: 0.1200
#   Epoch 9 | Batch 400/1322 | loss: 3.3397  acc: 0.1202
#   Epoch 9 | Batch 500/1322 | loss: 3.3384  acc: 0.1205
#   Epoch 9 | Batch 600/1322 | loss: 3.3361  acc: 0.1208
#   Epoch 9 | Batch 700/1322 | loss: 3.3341  acc: 0.1213
#   Epoch 9 | Batch 800/1322 | loss: 3.3316  acc: 0.1218
#   Epoch 9 | Batch 900/1322 | loss: 3.3298  acc: 0.1221
#   Epoch 9 | Batch 1000/1322 | loss: 3.3279  acc: 0.1224
#   Epoch 9 | Batch 1100/1322 | loss: 3.3258  acc: 0.1226
#   Epoch 9 | Batch 1200/1322 | loss: 3.3235  acc: 0.1229
#   Epoch 9 | Batch 1300/1322 | loss: 3.3213  acc: 0.1232
# Epoch 09/20 | train_loss: 3.3344  train_acc: 0.1211 | val_loss: 3.3186  val_acc: 0.1239 | 306.7s
#   💾 Saved best model (val_loss: 3.3186)
#   Epoch 10 | Batch 100/1322 | loss: 3.3169  acc: 0.1243
#   Epoch 10 | Batch 200/1322 | loss: 3.3155  acc: 0.1243
#   Epoch 10 | Batch 300/1322 | loss: 3.3132  acc: 0.1248
#   Epoch 10 | Batch 400/1322 | loss: 3.3113  acc: 0.1253
#   Epoch 10 | Batch 500/1322 | loss: 3.3092  acc: 0.1256
#   Epoch 10 | Batch 600/1322 | loss: 3.3073  acc: 0.1259
#   Epoch 10 | Batch 700/1322 | loss: 3.3056  acc: 0.1264
#   Epoch 10 | Batch 800/1322 | loss: 3.3042  acc: 0.1266
#   Epoch 10 | Batch 900/1322 | loss: 3.3025  acc: 0.1271
#   Epoch 10 | Batch 1000/1322 | loss: 3.3006  acc: 0.1274
#   Epoch 10 | Batch 1100/1322 | loss: 3.2988  acc: 0.1278
#   Epoch 10 | Batch 1200/1322 | loss: 3.2968  acc: 0.1283
#   Epoch 10 | Batch 1300/1322 | loss: 3.2954  acc: 0.1286
# Epoch 10/20 | train_loss: 3.3066  train_acc: 0.1262 | val_loss: 3.2928  val_acc: 0.1294 | 304.3s
#   💾 Saved best model (val_loss: 3.2928)
#   Epoch 11 | Batch 100/1322 | loss: 3.2911  acc: 0.1296
#   Epoch 11 | Batch 200/1322 | loss: 3.2894  acc: 0.1299
#   Epoch 11 | Batch 300/1322 | loss: 3.2878  acc: 0.1301
#   Epoch 11 | Batch 400/1322 | loss: 3.2861  acc: 0.1305
#   Epoch 11 | Batch 500/1322 | loss: 3.2844  acc: 0.1307
#   Epoch 11 | Batch 600/1322 | loss: 3.2829  acc: 0.1310
#   Epoch 11 | Batch 700/1322 | loss: 3.2814  acc: 0.1313
#   Epoch 11 | Batch 800/1322 | loss: 3.2797  acc: 0.1318
#   Epoch 11 | Batch 900/1322 | loss: 3.2782  acc: 0.1320
#   Epoch 11 | Batch 1000/1322 | loss: 3.2761  acc: 0.1324
#   Epoch 11 | Batch 1100/1322 | loss: 3.2744  acc: 0.1326
#   Epoch 11 | Batch 1200/1322 | loss: 3.2724  acc: 0.1330
#   Epoch 11 | Batch 1300/1322 | loss: 3.2709  acc: 0.1332
# Epoch 11/20 | train_loss: 3.2818  train_acc: 0.1313 | val_loss: 3.2688  val_acc: 0.1338 | 305.0s
#   💾 Saved best model (val_loss: 3.2688)
#   Epoch 12 | Batch 100/1322 | loss: 3.2669  acc: 0.1342
#   Epoch 12 | Batch 200/1322 | loss: 3.2652  acc: 0.1344
#   Epoch 12 | Batch 300/1322 | loss: 3.2636  acc: 0.1348
#   Epoch 12 | Batch 400/1322 | loss: 3.2621  acc: 0.1352
#   Epoch 12 | Batch 500/1322 | loss: 3.2605  acc: 0.1356
#   Epoch 12 | Batch 600/1322 | loss: 3.2587  acc: 0.1359
#   Epoch 12 | Batch 700/1322 | loss: 3.2578  acc: 0.1361
#   Epoch 12 | Batch 800/1322 | loss: 3.2563  acc: 0.1364
#   Epoch 12 | Batch 900/1322 | loss: 3.2549  acc: 0.1367
#   Epoch 12 | Batch 1000/1322 | loss: 3.2529  acc: 0.1369
#   Epoch 12 | Batch 1100/1322 | loss: 3.2513  acc: 0.1372
#   Epoch 12 | Batch 1200/1322 | loss: 3.2498  acc: 0.1376
#   Epoch 12 | Batch 1300/1322 | loss: 3.2485  acc: 0.1377
# Epoch 12/20 | train_loss: 3.2581  train_acc: 0.1360 | val_loss: 3.2461  val_acc: 0.1384 | 304.5s
#   💾 Saved best model (val_loss: 3.2461)
#   Epoch 13 | Batch 100/1322 | loss: 3.2445  acc: 0.1386
#   Epoch 13 | Batch 200/1322 | loss: 3.2426  acc: 0.1389
#   Epoch 13 | Batch 300/1322 | loss: 3.2409  acc: 0.1393
#   Epoch 13 | Batch 400/1322 | loss: 3.2395  acc: 0.1394
#   Epoch 13 | Batch 500/1322 | loss: 3.2384  acc: 0.1396
#   Epoch 13 | Batch 600/1322 | loss: 3.2371  acc: 0.1398
#   Epoch 13 | Batch 700/1322 | loss: 3.2358  acc: 0.1399
#   Epoch 13 | Batch 800/1322 | loss: 3.2349  acc: 0.1401
#   Epoch 13 | Batch 900/1322 | loss: 3.2333  acc: 0.1406
#   Epoch 13 | Batch 1000/1322 | loss: 3.2314  acc: 0.1410
#   Epoch 13 | Batch 1100/1322 | loss: 3.2298  acc: 0.1413
#   Epoch 13 | Batch 1200/1322 | loss: 3.2283  acc: 0.1416
#   Epoch 13 | Batch 1300/1322 | loss: 3.2267  acc: 0.1419
# Epoch 13/20 | train_loss: 3.2362  train_acc: 0.1400 | val_loss: 3.2243  val_acc: 0.1426 | 306.6s
#   💾 Saved best model (val_loss: 3.2243)
#   Epoch 14 | Batch 100/1322 | loss: 3.2225  acc: 0.1429
#   Epoch 14 | Batch 200/1322 | loss: 3.2208  acc: 0.1433
#   Epoch 14 | Batch 300/1322 | loss: 3.2195  acc: 0.1435
#   Epoch 14 | Batch 400/1322 | loss: 3.2182  acc: 0.1437
#   Epoch 14 | Batch 500/1322 | loss: 3.2165  acc: 0.1441
#   Epoch 14 | Batch 600/1322 | loss: 3.2155  acc: 0.1442
#   Epoch 14 | Batch 700/1322 | loss: 3.2137  acc: 0.1446
#   Epoch 14 | Batch 800/1322 | loss: 3.2128  acc: 0.1449
#   Epoch 14 | Batch 900/1322 | loss: 3.2115  acc: 0.1451
#   Epoch 14 | Batch 1000/1322 | loss: 3.2099  acc: 0.1453
#   Epoch 14 | Batch 1100/1322 | loss: 3.2086  acc: 0.1457
#   Epoch 14 | Batch 1200/1322 | loss: 3.2071  acc: 0.1460
#   Epoch 14 | Batch 1300/1322 | loss: 3.2059  acc: 0.1462
# Epoch 14/20 | train_loss: 3.2146  train_acc: 0.1445 | val_loss: 3.2042  val_acc: 0.1466 | 305.4s
#   💾 Saved best model (val_loss: 3.2042)
#   Epoch 15 | Batch 100/1322 | loss: 3.2026  acc: 0.1468
#   Epoch 15 | Batch 200/1322 | loss: 3.2014  acc: 0.1470
#   Epoch 15 | Batch 300/1322 | loss: 3.2001  acc: 0.1472
#   Epoch 15 | Batch 400/1322 | loss: 3.1986  acc: 0.1474
#   Epoch 15 | Batch 500/1322 | loss: 3.1973  acc: 0.1477
#   Epoch 15 | Batch 600/1322 | loss: 3.1958  acc: 0.1480
#   Epoch 15 | Batch 700/1322 | loss: 3.1943  acc: 0.1482
#   Epoch 15 | Batch 800/1322 | loss: 3.1930  acc: 0.1485
#   Epoch 15 | Batch 900/1322 | loss: 3.1916  acc: 0.1488
#   Epoch 15 | Batch 1000/1322 | loss: 3.1902  acc: 0.1491
#   Epoch 15 | Batch 1100/1322 | loss: 3.1887  acc: 0.1495
#   Epoch 15 | Batch 1200/1322 | loss: 3.1876  acc: 0.1496
#   Epoch 15 | Batch 1300/1322 | loss: 3.1863  acc: 0.1498
# Epoch 15/20 | train_loss: 3.1950  train_acc: 0.1482 | val_loss: 3.1846  val_acc: 0.1503 | 307.4s
#   💾 Saved best model (val_loss: 3.1846)
#   Epoch 16 | Batch 100/1322 | loss: 3.1832  acc: 0.1505
#   Epoch 16 | Batch 200/1322 | loss: 3.1818  acc: 0.1509
#   Epoch 16 | Batch 300/1322 | loss: 3.1801  acc: 0.1515
#   Epoch 16 | Batch 400/1322 | loss: 3.1783  acc: 0.1517
#   Epoch 16 | Batch 500/1322 | loss: 3.1773  acc: 0.1519
#   Epoch 16 | Batch 600/1322 | loss: 3.1761  acc: 0.1521
#   Epoch 16 | Batch 700/1322 | loss: 3.1745  acc: 0.1523
#   Epoch 16 | Batch 800/1322 | loss: 3.1731  acc: 0.1527
#   Epoch 16 | Batch 900/1322 | loss: 3.1717  acc: 0.1530
#   Epoch 16 | Batch 1000/1322 | loss: 3.1707  acc: 0.1530
#   Epoch 16 | Batch 1100/1322 | loss: 3.1694  acc: 0.1532
#   Epoch 16 | Batch 1200/1322 | loss: 3.1680  acc: 0.1534
#   Epoch 16 | Batch 1300/1322 | loss: 3.1671  acc: 0.1537
# Epoch 16/20 | train_loss: 3.1752  train_acc: 0.1522 | val_loss: 3.1661  val_acc: 0.1540 | 304.0s
#   💾 Saved best model (val_loss: 3.1661)
#   Epoch 17 | Batch 100/1322 | loss: 3.1655  acc: 0.1541
#   Epoch 17 | Batch 200/1322 | loss: 3.1642  acc: 0.1545
#   Epoch 17 | Batch 300/1322 | loss: 3.1630  acc: 0.1548
#   Epoch 17 | Batch 400/1322 | loss: 3.1620  acc: 0.1550
#   Epoch 17 | Batch 500/1322 | loss: 3.1607  acc: 0.1551
#   Epoch 17 | Batch 600/1322 | loss: 3.1595  acc: 0.1553
#   Epoch 17 | Batch 700/1322 | loss: 3.1584  acc: 0.1554
#   Epoch 17 | Batch 800/1322 | loss: 3.1569  acc: 0.1557
#   Epoch 17 | Batch 900/1322 | loss: 3.1553  acc: 0.1561
#   Epoch 17 | Batch 1000/1322 | loss: 3.1540  acc: 0.1563
#   Epoch 17 | Batch 1100/1322 | loss: 3.1526  acc: 0.1565
#   Epoch 17 | Batch 1200/1322 | loss: 3.1512  acc: 0.1568
#   Epoch 17 | Batch 1300/1322 | loss: 3.1501  acc: 0.1570
# Epoch 17/20 | train_loss: 3.1585  train_acc: 0.1555 | val_loss: 3.1485  val_acc: 0.1575 | 312.6s
#   💾 Saved best model (val_loss: 3.1485)
#   Epoch 18 | Batch 100/1322 | loss: 3.1474  acc: 0.1578
#   Epoch 18 | Batch 200/1322 | loss: 3.1460  acc: 0.1581
#   Epoch 18 | Batch 300/1322 | loss: 3.1445  acc: 0.1585
#   Epoch 18 | Batch 400/1322 | loss: 3.1434  acc: 0.1587
#   Epoch 18 | Batch 500/1322 | loss: 3.1422  acc: 0.1588
#   Epoch 18 | Batch 600/1322 | loss: 3.1408  acc: 0.1590
#   Epoch 18 | Batch 700/1322 | loss: 3.1396  acc: 0.1593
#   Epoch 18 | Batch 800/1322 | loss: 3.1383  acc: 0.1596
#   Epoch 18 | Batch 900/1322 | loss: 3.1372  acc: 0.1599
#   Epoch 18 | Batch 1000/1322 | loss: 3.1357  acc: 0.1601
#   Epoch 18 | Batch 1100/1322 | loss: 3.1347  acc: 0.1602
#   Epoch 18 | Batch 1200/1322 | loss: 3.1336  acc: 0.1604
#   Epoch 18 | Batch 1300/1322 | loss: 3.1323  acc: 0.1607
# Epoch 18/20 | train_loss: 3.1402  train_acc: 0.1592 | val_loss: 3.1304  val_acc: 0.1612 | 311.2s
#   💾 Saved best model (val_loss: 3.1304)
#   Epoch 19 | Batch 100/1322 | loss: 3.1293  acc: 0.1613
#   Epoch 19 | Batch 200/1322 | loss: 3.1279  acc: 0.1616
#   Epoch 19 | Batch 300/1322 | loss: 3.1267  acc: 0.1618
#   Epoch 19 | Batch 400/1322 | loss: 3.1254  acc: 0.1620
#   Epoch 19 | Batch 500/1322 | loss: 3.1238  acc: 0.1623
#   Epoch 19 | Batch 600/1322 | loss: 3.1226  acc: 0.1626
#   Epoch 19 | Batch 700/1322 | loss: 3.1218  acc: 0.1627
#   Epoch 19 | Batch 800/1322 | loss: 3.1206  acc: 0.1630
#   Epoch 19 | Batch 900/1322 | loss: 3.1193  acc: 0.1633
#   Epoch 19 | Batch 1000/1322 | loss: 3.1184  acc: 0.1634
#   Epoch 19 | Batch 1100/1322 | loss: 3.1173  acc: 0.1636
#   Epoch 19 | Batch 1200/1322 | loss: 3.1161  acc: 0.1638
#   Epoch 19 | Batch 1300/1322 | loss: 3.1146  acc: 0.1642
# Epoch 19/20 | train_loss: 3.1223  train_acc: 0.1627 | val_loss: 3.1128  val_acc: 0.1647 | 312.1s
#   💾 Saved best model (val_loss: 3.1128)
#   Epoch 20 | Batch 100/1322 | loss: 3.1112  acc: 0.1650
#   Epoch 20 | Batch 200/1322 | loss: 3.1099  acc: 0.1652
#   Epoch 20 | Batch 300/1322 | loss: 3.1086  acc: 0.1655
#   Epoch 20 | Batch 400/1322 | loss: 3.1078  acc: 0.1657
#   Epoch 20 | Batch 500/1322 | loss: 3.1069  acc: 0.1659
#   Epoch 20 | Batch 600/1322 | loss: 3.1057  acc: 0.1661
#   Epoch 20 | Batch 700/1322 | loss: 3.1043  acc: 0.1664
#   Epoch 20 | Batch 800/1322 | loss: 3.1031  acc: 0.1668
#   Epoch 20 | Batch 900/1322 | loss: 3.1016  acc: 0.1670
#   Epoch 20 | Batch 1000/1322 | loss: 3.1005  acc: 0.1672
#   Epoch 20 | Batch 1100/1322 | loss: 3.0992  acc: 0.1674
#   Epoch 20 | Batch 1200/1322 | loss: 3.0981  acc: 0.1676
#   Epoch 20 | Batch 1300/1322 | loss: 3.0970  acc: 0.1679
# Epoch 20/20 | train_loss: 3.1046  train_acc: 0.1663 | val_loss: 3.0955  val_acc: 0.1683 | 306.3s
#   💾 Saved best model (val_loss: 3.0955)
#
# ✅ Training complete. Best val_loss: 3.0955
