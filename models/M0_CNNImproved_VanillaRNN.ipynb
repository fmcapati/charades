# %% [markdown]
# ## M0_CNNImproved_VanillaRNN
#
# Improved CNN backbone (32→64→128 filters vs 16→32→64 in M0) paired with a Vanilla RNN. Same 3-block structure — doubled filter capacity per layer for a controlled comparison.

# %%
import torch, gc
gc.collect()
torch.cuda.empty_cache()
print(f"GPU free: {(torch.cuda.get_device_properties(0).total_memory - torch.cuda.memory_reserved(0))/1024**3:.2f} GiB")
# Out:
# GPU free: 10.90 GiB

# %%
import os, gc, time, csv, cv2
os.environ["KERAS_BACKEND"]               = "torch"
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"
os.environ["PYTORCH_CUDA_ALLOC_CONF"]     = "expandable_segments:True"

import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from pathlib import Path
import keras
from keras import layers, optimizers

# ── Reproducibility ───────────────────────────────────────────────────────────
SEED = 42
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ── Paths ─────────────────────────────────────────────────────────────────────
DATA_DIR    = Path("/home2/msds2026/fcapati/ml3_2026/Projects/Final_Project/data")
FRAMES_DIR  = DATA_DIR / "UCF50_frames"
DATASET_DIR = DATA_DIR / "UCF50"

# ── Config ────────────────────────────────────────────────────────────────────
IMG_HEIGHT      = 64
IMG_WIDTH       = 64
SEQUENCE_LENGTH = 16
BATCH_SIZE      = 4
EPOCHS          = 20
LEARNING_RATE   = 1e-4
NUM_CLASSES     = 50

# ── Class mapping ─────────────────────────────────────────────────────────────
CLASS_NAMES_SORTED = sorted([d.name for d in DATASET_DIR.iterdir() if d.is_dir()])
class_to_idx       = {cls: idx for idx, cls in enumerate(CLASS_NAMES_SORTED)}
idx_to_class       = {idx: cls for cls, idx in class_to_idx.items()}

print(f"✅ Keras backend : {keras.backend.backend()}")
print(f"✅ Device        : {DEVICE}")
print(f"✅ Classes       : {len(class_to_idx)}")
print(f"✅ Frames dir    : {FRAMES_DIR.exists()}")
# Out:
# ✅ Keras backend : torch
# ✅ Device        : cuda
# ✅ Classes       : 50
# ✅ Frames dir    : True

# %%
class PreextractedDataset(Dataset):
    """Loads pre-extracted .npy frame arrays — fast, no video I/O during training."""
    def __init__(self, frames_dir, split, class_to_idx):
        self.samples = []
        for class_dir in sorted((Path(frames_dir) / split).iterdir()):
            if not class_dir.is_dir():
                continue
            label = class_to_idx[class_dir.name]
            for npy_path in sorted(class_dir.glob("*.npy")):
                self.samples.append((str(npy_path), label))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        npy_path, label = self.samples[idx]
        frames = np.load(npy_path)  # (16, 112, 112, 3)
        
        # Resize to target resolution if needed
        if frames.shape[1] != IMG_HEIGHT:
            frames = np.stack([
                cv2.resize(f, (IMG_WIDTH, IMG_HEIGHT)) for f in frames
            ])
        
        frames = torch.tensor(frames).permute(3, 0, 1, 2).float()
        return frames, torch.tensor(label, dtype=torch.long)


train_dataset = PreextractedDataset(FRAMES_DIR, "train", class_to_idx)
val_dataset   = PreextractedDataset(FRAMES_DIR, "val",   class_to_idx)
test_dataset  = PreextractedDataset(FRAMES_DIR, "test",  class_to_idx)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,
                          num_workers=0, pin_memory=False)
val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=0, pin_memory=False)
test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=0, pin_memory=False)

print(f"✅ Train : {len(train_dataset):,} videos → {len(train_loader)} steps/epoch")
print(f"✅ Val   : {len(val_dataset):,} videos → {len(val_loader)} steps/epoch")
print(f"✅ Test  : {len(test_dataset):,} videos → {len(test_loader)} steps/epoch")

sample_frames, sample_labels = next(iter(train_loader))
print(f"\nBatch frames : {sample_frames.shape}  → (B, C, T, H, W)")
print(f"Batch labels : {sample_labels.shape}  dtype={sample_labels.dtype}")
# Out:
# ✅ Train : 5,288 videos → 1322 steps/epoch
# ✅ Val   : 640 videos → 160 steps/epoch
# ✅ Test  : 698 videos → 175 steps/epoch
#
# Batch frames : torch.Size([4, 3, 16, 64, 64])  → (B, C, T, H, W)
# Batch labels : torch.Size([4])  dtype=torch.int64

# %%
def train_model_keras(model, model_name, train_loader, val_loader, epochs=EPOCHS):
    """
    Training loop for Keras (torch backend) with PyTorch DataLoader.
    Features: per-batch cache clearing, early stopping (patience=5),
    checkpointing, CSV history logging, flush=True for real-time output.
    """
    gc.collect()
    torch.cuda.empty_cache()
    print(f"GPU memory reserved: {torch.cuda.memory_reserved()/1024**3:.2f} GiB", flush=True)

    model.compile(
        optimizer = optimizers.Adam(learning_rate=LEARNING_RATE),
        loss      = "sparse_categorical_crossentropy",
        metrics   = ["accuracy"]
    )

    best_val_loss  = float("inf")
    patience_count = 0
    patience       = 5
    history        = []

    print(f"\n{'='*60}", flush=True)
    print(f"Training: {model_name}", flush=True)
    print(f"{'='*60}", flush=True)

    for epoch in range(1, epochs + 1):
        t0 = time.time()

        # ── Training ──────────────────────────────────────────────────────────
        train_losses, train_accs = [], []
        for batch_idx, (frames, labels) in enumerate(train_loader):
            frames_np = frames.permute(0, 2, 3, 4, 1).numpy()
            labels_np = labels.numpy()
            metrics   = model.train_on_batch(frames_np, labels_np)
            train_losses.append(metrics[0])
            train_accs.append(metrics[1])

            if (batch_idx + 1) % 50 == 0:
                torch.cuda.empty_cache()

            if (batch_idx + 1) % 100 == 0:
                print(f"  Epoch {epoch} | Batch {batch_idx+1}/{len(train_loader)} | "
                      f"loss: {metrics[0]:.4f}  acc: {metrics[1]:.4f}", flush=True)

        # ── Validation ────────────────────────────────────────────────────────
        val_losses, val_accs = [], []
        for frames, labels in val_loader:
            frames_np = frames.permute(0, 2, 3, 4, 1).numpy()
            labels_np = labels.numpy()
            metrics   = model.test_on_batch(frames_np, labels_np)
            val_losses.append(metrics[0])
            val_accs.append(metrics[1])

        train_loss = sum(train_losses) / len(train_losses)
        train_acc  = sum(train_accs)  / len(train_accs)
        val_loss   = sum(val_losses)  / len(val_losses)
        val_acc    = sum(val_accs)    / len(val_accs)
        elapsed    = time.time() - t0

        history.append({
            "epoch": epoch, "train_loss": train_loss, "train_acc": train_acc,
            "val_loss": val_loss, "val_acc": val_acc
        })

        print(f"Epoch {epoch:02d}/{epochs} | "
              f"train_loss: {train_loss:.4f}  train_acc: {train_acc:.4f} | "
              f"val_loss: {val_loss:.4f}  val_acc: {val_acc:.4f} | "
              f"{elapsed:.1f}s", flush=True)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            model.save(f"best_{model_name}.keras")
            print(f"  💾 Saved best model (val_loss: {best_val_loss:.4f})", flush=True)
            patience_count = 0
        else:
            patience_count += 1
            print(f"  ⏳ No improvement ({patience_count}/{patience})", flush=True)
            if patience_count >= patience:
                print(f"\nEarly stopping at epoch {epoch}.", flush=True)
                break

    with open(f"history_{model_name}.csv", "w", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=history[0].keys())
        writer.writeheader()
        writer.writerows(history)

    print(f"\n✅ Training complete. Best val_loss: {best_val_loss:.4f}", flush=True)
    return model, history

print("✅ Training loop ready")
# Out:
# ✅ Training loop ready

# %% [markdown]
# ### Model Definition
#
# Identical to M0 except CNN filters are doubled (32→64→128). This tests whether increased spatial feature capacity improves performance independent of the recurrent unit choice, without adding extra pooling layers that would reduce spatial resolution.

# %%
# ── M0_CNNImproved_VanillaRNN ──────────────────────────────────────────────────────
# Increased CNN filters from 16→32→64 to 32→64→128.
# Same 3-block structure as baseline — more capacity per layer, not more layers.
# All other hyperparameters kept identical for a controlled comparison.

inputs = keras.Input(shape=(SEQUENCE_LENGTH, IMG_HEIGHT, IMG_WIDTH, 3))

# ── TimeDistributed CNN Block (32→64→128 vs 16→32→64 in baseline) ────────────
x = layers.TimeDistributed(layers.Conv2D(32, (3,3), activation="relu", padding="same"))(inputs)
x = layers.TimeDistributed(layers.MaxPooling2D((2,2)))(x)

x = layers.TimeDistributed(layers.Conv2D(64, (3,3), activation="relu", padding="same"))(x)
x = layers.TimeDistributed(layers.MaxPooling2D((2,2)))(x)

x = layers.TimeDistributed(layers.Conv2D(128, (3,3), activation="relu", padding="same"))(x)
x = layers.TimeDistributed(layers.GlobalAveragePooling2D())(x)

# ── SimpleRNN Temporal Block ──────────────────────────────────────────────
# Vanilla RNN: h_t = tanh(W_h * h_{t-1} + W_x * x_t + b). No gating.
x = layers.SimpleRNN(128, return_sequences=False)(x)
x = layers.Dense(256, activation="relu")(x)
outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)

model = keras.Model(inputs, outputs, name="M0_CNNImproved_VanillaRNN")

total_params = sum(int(np.prod(w.shape)) for w in model.weights)
print(f"Model     : M0_CNNImproved_VanillaRNN")
print(f"Params    : {total_params:,}")
model.summary()
# Out:
# Model     : M0_CNNImproved_VanillaRNN
# Params    : 172,018
# Model: "M0_CNNImproved_VanillaRNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 16, 64, 64, 3)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 16, 64, 64, 32) │           896 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 16, 32, 32, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 16, 32, 32, 64) │        18,496 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_3              │ (None, 16, 16, 16, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_4              │ (None, 16, 16, 16,     │        73,856 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_5              │ (None, 16, 128)        │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 50)             │        12,850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 172,018 (671.95 KB)
#  Trainable params: 172,018 (671.95 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Training

# %%
# ── Train M0_CNNImproved_VanillaRNN ────────────────────────────────────────────────────────
model, history = train_model_keras(model, "M0_CNNImproved_VanillaRNN", train_loader, val_loader)
# Out:
# GPU memory reserved: 0.00 GiB
#
# ============================================================
# Training: M0_CNNImproved_VanillaRNN
# ============================================================
#   Epoch 1 | Batch 100/1322 | loss: 3.9239  acc: 0.0100
#   Epoch 1 | Batch 200/1322 | loss: 3.9156  acc: 0.0262
#   Epoch 1 | Batch 300/1322 | loss: 3.9084  acc: 0.0325
#   Epoch 1 | Batch 400/1322 | loss: 3.8991  acc: 0.0362
#   Epoch 1 | Batch 500/1322 | loss: 3.8798  acc: 0.0415
#   Epoch 1 | Batch 600/1322 | loss: 3.8532  acc: 0.0454
#   Epoch 1 | Batch 700/1322 | loss: 3.8269  acc: 0.0493
#   Epoch 1 | Batch 800/1322 | loss: 3.8066  acc: 0.0516
#   Epoch 1 | Batch 900/1322 | loss: 3.7897  acc: 0.0536
#   Epoch 1 | Batch 1000/1322 | loss: 3.7763  acc: 0.0545
#   Epoch 1 | Batch 1100/1322 | loss: 3.7611  acc: 0.0570
#   Epoch 1 | Batch 1200/1322 | loss: 3.7399  acc: 0.0577
#   Epoch 1 | Batch 1300/1322 | loss: 3.7253  acc: 0.0596
# Epoch 01/20 | train_loss: 3.8370  train_acc: 0.0431 | val_loss: 3.7021  val_acc: 0.0631 | 386.6s
#   💾 Saved best model (val_loss: 3.7021)
#   Epoch 2 | Batch 100/1322 | loss: 3.6889  acc: 0.0643
#   Epoch 2 | Batch 200/1322 | loss: 3.6764  acc: 0.0661
#   Epoch 2 | Batch 300/1322 | loss: 3.6663  acc: 0.0673
#   Epoch 2 | Batch 400/1322 | loss: 3.6560  acc: 0.0684
#   Epoch 2 | Batch 500/1322 | loss: 3.6438  acc: 0.0704
#   Epoch 2 | Batch 600/1322 | loss: 3.6329  acc: 0.0722
#   Epoch 2 | Batch 700/1322 | loss: 3.6183  acc: 0.0744
#   Epoch 2 | Batch 800/1322 | loss: 3.6087  acc: 0.0761
#   Epoch 2 | Batch 900/1322 | loss: 3.5997  acc: 0.0771
#   Epoch 2 | Batch 1000/1322 | loss: 3.5884  acc: 0.0787
#   Epoch 2 | Batch 1100/1322 | loss: 3.5790  acc: 0.0806
#   Epoch 2 | Batch 1200/1322 | loss: 3.5753  acc: 0.0808
#   Epoch 2 | Batch 1300/1322 | loss: 3.5692  acc: 0.0817
#   Epoch 3 | Batch 400/1322 | loss: 3.5258  acc: 0.0890
#   Epoch 3 | Batch 500/1322 | loss: 3.5180  acc: 0.0900
#   Epoch 3 | Batch 600/1322 | loss: 3.5097  acc: 0.0921
#   Epoch 3 | Batch 700/1322 | loss: 3.5052  acc: 0.0938
#   Epoch 3 | Batch 800/1322 | loss: 3.4993  acc: 0.0945
#   Epoch 3 | Batch 900/1322 | loss: 3.4935  acc: 0.0952
#   Epoch 3 | Batch 1000/1322 | loss: 3.4887  acc: 0.0959
#   Epoch 3 | Batch 1100/1322 | loss: 3.4833  acc: 0.0968
#   Epoch 3 | Batch 1200/1322 | loss: 3.4768  acc: 0.0982
#   Epoch 3 | Batch 1300/1322 | loss: 3.4713  acc: 0.0985
# Epoch 03/20 | train_loss: 3.5096  train_acc: 0.0922 | val_loss: 3.4638  val_acc: 0.1007 | 354.7s
#   💾 Saved best model (val_loss: 3.4638)
#   Epoch 4 | Batch 100/1322 | loss: 3.4581  acc: 0.1014
#   Epoch 4 | Batch 200/1322 | loss: 3.4536  acc: 0.1013
#   Epoch 4 | Batch 300/1322 | loss: 3.4482  acc: 0.1027
#   Epoch 4 | Batch 400/1322 | loss: 3.4425  acc: 0.1038
#   Epoch 4 | Batch 500/1322 | loss: 3.4366  acc: 0.1045
#   Epoch 4 | Batch 600/1322 | loss: 3.4305  acc: 0.1054
#   Epoch 4 | Batch 700/1322 | loss: 3.4270  acc: 0.1058
#   Epoch 4 | Batch 800/1322 | loss: 3.4235  acc: 0.1065
#   Epoch 4 | Batch 900/1322 | loss: 3.4198  acc: 0.1069
#   Epoch 4 | Batch 1000/1322 | loss: 3.4153  acc: 0.1073
#   Epoch 4 | Batch 1100/1322 | loss: 3.4115  acc: 0.1081
#   Epoch 4 | Batch 1200/1322 | loss: 3.4076  acc: 0.1089
#   Epoch 4 | Batch 1300/1322 | loss: 3.4030  acc: 0.1103
# Epoch 04/20 | train_loss: 3.4308  train_acc: 0.1053 | val_loss: 3.3973  val_acc: 0.1122 | 356.8s
#   💾 Saved best model (val_loss: 3.3973)
#   Epoch 5 | Batch 100/1322 | loss: 3.3911  acc: 0.1130
#   Epoch 5 | Batch 200/1322 | loss: 3.3870  acc: 0.1135
#   Epoch 5 | Batch 300/1322 | loss: 3.3838  acc: 0.1138
#   Epoch 5 | Batch 400/1322 | loss: 3.3810  acc: 0.1139
#   Epoch 5 | Batch 500/1322 | loss: 3.3759  acc: 0.1148
#   Epoch 5 | Batch 600/1322 | loss: 3.3725  acc: 0.1153
#   Epoch 5 | Batch 700/1322 | loss: 3.3682  acc: 0.1161
#   Epoch 5 | Batch 800/1322 | loss: 3.3639  acc: 0.1169
#   Epoch 5 | Batch 900/1322 | loss: 3.3606  acc: 0.1176
#   Epoch 5 | Batch 1000/1322 | loss: 3.3557  acc: 0.1186
#   Epoch 5 | Batch 1100/1322 | loss: 3.3524  acc: 0.1197
#   Epoch 5 | Batch 1200/1322 | loss: 3.3495  acc: 0.1202
#   Epoch 5 | Batch 1300/1322 | loss: 3.3462  acc: 0.1210
# Epoch 05/20 | train_loss: 3.3697  train_acc: 0.1163 | val_loss: 3.3409  val_acc: 0.1223 | 355.9s
#   💾 Saved best model (val_loss: 3.3409)
#   Epoch 6 | Batch 100/1322 | loss: 3.3361  acc: 0.1233
#   Epoch 6 | Batch 500/1322 | loss: 3.3222  acc: 0.1253
#   Epoch 6 | Batch 600/1322 | loss: 3.3185  acc: 0.1260
#   Epoch 6 | Batch 700/1322 | loss: 3.3147  acc: 0.1266
#   Epoch 6 | Batch 800/1322 | loss: 3.3113  acc: 0.1273
#   Epoch 6 | Batch 900/1322 | loss: 3.3086  acc: 0.1279
#   Epoch 6 | Batch 1000/1322 | loss: 3.3045  acc: 0.1286
#   Epoch 6 | Batch 1100/1322 | loss: 3.3013  acc: 0.1291
#   Epoch 6 | Batch 1200/1322 | loss: 3.2977  acc: 0.1298
#   Epoch 6 | Batch 1300/1322 | loss: 3.2946  acc: 0.1307
# Epoch 06/20 | train_loss: 3.3165  train_acc: 0.1265 | val_loss: 3.2912  val_acc: 0.1314 | 351.7s
#   💾 Saved best model (val_loss: 3.2912)
#   Epoch 7 | Batch 100/1322 | loss: 3.2875  acc: 0.1321
#   Epoch 7 | Batch 200/1322 | loss: 3.2833  acc: 0.1329
#   Epoch 7 | Batch 300/1322 | loss: 3.2792  acc: 0.1337
#   Epoch 7 | Batch 400/1322 | loss: 3.2756  acc: 0.1346
#   Epoch 7 | Batch 500/1322 | loss: 3.2719  acc: 0.1353
#   Epoch 7 | Batch 600/1322 | loss: 3.2688  acc: 0.1359
#   Epoch 7 | Batch 700/1322 | loss: 3.2646  acc: 0.1369
#   Epoch 7 | Batch 800/1322 | loss: 3.2615  acc: 0.1374
#   Epoch 7 | Batch 900/1322 | loss: 3.2571  acc: 0.1385
#   Epoch 7 | Batch 1000/1322 | loss: 3.2541  acc: 0.1391
#   Epoch 7 | Batch 1100/1322 | loss: 3.2511  acc: 0.1399
#   Epoch 7 | Batch 1200/1322 | loss: 3.2472  acc: 0.1405
#   Epoch 7 | Batch 1300/1322 | loss: 3.2439  acc: 0.1412
# Epoch 07/20 | train_loss: 3.2664  train_acc: 0.1365 | val_loss: 3.2391  val_acc: 0.1427 | 350.1s
#   💾 Saved best model (val_loss: 3.2391)
#   Epoch 8 | Batch 100/1322 | loss: 3.2339  acc: 0.1434
#   Epoch 8 | Batch 200/1322 | loss: 3.2311  acc: 0.1441
#   Epoch 8 | Batch 300/1322 | loss: 3.2270  acc: 0.1448
#   Epoch 8 | Batch 400/1322 | loss: 3.2234  acc: 0.1453
#   Epoch 8 | Batch 500/1322 | loss: 3.2209  acc: 0.1458
#   Epoch 8 | Batch 600/1322 | loss: 3.2164  acc: 0.1466
#   Epoch 8 | Batch 700/1322 | loss: 3.2132  acc: 0.1472
#   Epoch 8 | Batch 800/1322 | loss: 3.2098  acc: 0.1478
#   Epoch 8 | Batch 900/1322 | loss: 3.2066  acc: 0.1484
#   Epoch 8 | Batch 1000/1322 | loss: 3.2039  acc: 0.1489
#   Epoch 8 | Batch 1100/1322 | loss: 3.1998  acc: 0.1496
#   Epoch 8 | Batch 1200/1322 | loss: 3.1969  acc: 0.1501
#   Epoch 9 | Batch 200/1322 | loss: 3.1801  acc: 0.1541
#   Epoch 9 | Batch 300/1322 | loss: 3.1761  acc: 0.1549
#   Epoch 9 | Batch 400/1322 | loss: 3.1736  acc: 0.1554
#   Epoch 9 | Batch 500/1322 | loss: 3.1713  acc: 0.1559
#   Epoch 9 | Batch 600/1322 | loss: 3.1682  acc: 0.1565
#   Epoch 9 | Batch 700/1322 | loss: 3.1644  acc: 0.1573
#   Epoch 9 | Batch 800/1322 | loss: 3.1604  acc: 0.1582
#   Epoch 9 | Batch 900/1322 | loss: 3.1575  acc: 0.1588
#   Epoch 9 | Batch 1000/1322 | loss: 3.1544  acc: 0.1593
#   Epoch 9 | Batch 1100/1322 | loss: 3.1510  acc: 0.1600
#   Epoch 9 | Batch 1200/1322 | loss: 3.1475  acc: 0.1606
#   Epoch 9 | Batch 1300/1322 | loss: 3.1439  acc: 0.1613
# Epoch 09/20 | train_loss: 3.1653  train_acc: 0.1571 | val_loss: 3.1395  val_acc: 0.1623 | 360.3s
#   💾 Saved best model (val_loss: 3.1395)
#   Epoch 10 | Batch 100/1322 | loss: 3.1352  acc: 0.1631
#   Epoch 10 | Batch 200/1322 | loss: 3.1326  acc: 0.1636
#   Epoch 10 | Batch 300/1322 | loss: 3.1290  acc: 0.1641
#   Epoch 10 | Batch 400/1322 | loss: 3.1254  acc: 0.1648
#   Epoch 10 | Batch 500/1322 | loss: 3.1220  acc: 0.1655
#   Epoch 10 | Batch 600/1322 | loss: 3.1184  acc: 0.1661
#   Epoch 10 | Batch 700/1322 | loss: 3.1154  acc: 0.1667
#   Epoch 10 | Batch 800/1322 | loss: 3.1129  acc: 0.1673
#   Epoch 10 | Batch 900/1322 | loss: 3.1096  acc: 0.1681
#   Epoch 10 | Batch 1000/1322 | loss: 3.1063  acc: 0.1688
#   Epoch 10 | Batch 1100/1322 | loss: 3.1031  acc: 0.1696
#   Epoch 10 | Batch 1200/1322 | loss: 3.0997  acc: 0.1703
#   Epoch 10 | Batch 1300/1322 | loss: 3.0976  acc: 0.1707
# Epoch 10/20 | train_loss: 3.1171  train_acc: 0.1666 | val_loss: 3.0941  val_acc: 0.1717 | 353.1s
#   💾 Saved best model (val_loss: 3.0941)
#   Epoch 11 | Batch 100/1322 | loss: 3.0903  acc: 0.1725
#   Epoch 11 | Batch 200/1322 | loss: 3.0865  acc: 0.1733
#   Epoch 11 | Batch 300/1322 | loss: 3.0833  acc: 0.1739
#   Epoch 11 | Batch 400/1322 | loss: 3.0799  acc: 0.1747
#   Epoch 11 | Batch 500/1322 | loss: 3.0766  acc: 0.1753
#   Epoch 11 | Batch 600/1322 | loss: 3.0736  acc: 0.1761
#   Epoch 11 | Batch 700/1322 | loss: 3.0710  acc: 0.1766
#   Epoch 11 | Batch 800/1322 | loss: 3.0685  acc: 0.1773
#   Epoch 11 | Batch 900/1322 | loss: 3.0658  acc: 0.1777
#   Epoch 11 | Batch 1000/1322 | loss: 3.0620  acc: 0.1784
#   Epoch 11 | Batch 1100/1322 | loss: 3.0591  acc: 0.1790
#   Epoch 11 | Batch 1200/1322 | loss: 3.0558  acc: 0.1798
#   Epoch 11 | Batch 1300/1322 | loss: 3.0529  acc: 0.1805
# Epoch 11/20 | train_loss: 3.0724  train_acc: 0.1763 | val_loss: 3.0495  val_acc: 0.1813 | 350.2s
#   💾 Saved best model (val_loss: 3.0495)
#   Epoch 12 | Batch 100/1322 | loss: 3.0461  acc: 0.1821
#   Epoch 12 | Batch 200/1322 | loss: 3.0432  acc: 0.1828
#   Epoch 12 | Batch 300/1322 | loss: 3.0401  acc: 0.1835
#   Epoch 12 | Batch 400/1322 | loss: 3.0371  acc: 0.1844
#   Epoch 12 | Batch 500/1322 | loss: 3.0332  acc: 0.1853
#   Epoch 12 | Batch 600/1322 | loss: 3.0300  acc: 0.1859
#   Epoch 12 | Batch 700/1322 | loss: 3.0275  acc: 0.1864
#   Epoch 12 | Batch 800/1322 | loss: 3.0248  acc: 0.1870
#   Epoch 12 | Batch 900/1322 | loss: 3.0225  acc: 0.1874
#   Epoch 12 | Batch 1000/1322 | loss: 3.0194  acc: 0.1880
#   Epoch 12 | Batch 1100/1322 | loss: 3.0164  acc: 0.1886
#   Epoch 12 | Batch 1200/1322 | loss: 3.0137  acc: 0.1893
#   Epoch 12 | Batch 1300/1322 | loss: 3.0111  acc: 0.1898
# Epoch 12/20 | train_loss: 3.0292  train_acc: 0.1860 | val_loss: 3.0073  val_acc: 0.1909 | 352.9s
#   💾 Saved best model (val_loss: 3.0073)
#   Epoch 13 | Batch 100/1322 | loss: 3.0035  acc: 0.1917
#   Epoch 13 | Batch 200/1322 | loss: 3.0006  acc: 0.1923
#   Epoch 13 | Batch 300/1322 | loss: 2.9978  acc: 0.1929
#   Epoch 13 | Batch 400/1322 | loss: 2.9951  acc: 0.1934
#   Epoch 13 | Batch 500/1322 | loss: 2.9924  acc: 0.1940
#   Epoch 13 | Batch 600/1322 | loss: 2.9897  acc: 0.1946
#   Epoch 13 | Batch 700/1322 | loss: 2.9872  acc: 0.1951
#   Epoch 13 | Batch 800/1322 | loss: 2.9849  acc: 0.1955
#   Epoch 13 | Batch 900/1322 | loss: 2.9819  acc: 0.1961
#   Epoch 13 | Batch 1000/1322 | loss: 2.9785  acc: 0.1969
#   Epoch 13 | Batch 1100/1322 | loss: 2.9756  acc: 0.1976
#   Epoch 13 | Batch 1200/1322 | loss: 2.9729  acc: 0.1982
#   Epoch 13 | Batch 1300/1322 | loss: 2.9701  acc: 0.1988
# Epoch 13/20 | train_loss: 2.9880  train_acc: 0.1949 | val_loss: 2.9670  val_acc: 0.1995 | 380.9s
#   💾 Saved best model (val_loss: 2.9670)
#   Epoch 14 | Batch 100/1322 | loss: 2.9638  acc: 0.2000
#   Epoch 14 | Batch 200/1322 | loss: 2.9608  acc: 0.2006
#   Epoch 14 | Batch 300/1322 | loss: 2.9580  acc: 0.2012
#   Epoch 14 | Batch 400/1322 | loss: 2.9552  acc: 0.2019
#   Epoch 14 | Batch 500/1322 | loss: 2.9522  acc: 0.2025
#   Epoch 14 | Batch 600/1322 | loss: 2.9495  acc: 0.2032
#   Epoch 14 | Batch 700/1322 | loss: 2.9465  acc: 0.2038
#   Epoch 14 | Batch 800/1322 | loss: 2.9440  acc: 0.2044
#   Epoch 14 | Batch 900/1322 | loss: 2.9415  acc: 0.2050
#   Epoch 14 | Batch 1000/1322 | loss: 2.9384  acc: 0.2058
#   Epoch 14 | Batch 1100/1322 | loss: 2.9356  acc: 0.2065
#   Epoch 14 | Batch 1200/1322 | loss: 2.9324  acc: 0.2071
#   Epoch 14 | Batch 1300/1322 | loss: 2.9301  acc: 0.2075
# Epoch 14/20 | train_loss: 2.9479  train_acc: 0.2036 | val_loss: 2.9274  val_acc: 0.2081 | 390.0s
#   💾 Saved best model (val_loss: 2.9274)
#   Epoch 15 | Batch 100/1322 | loss: 2.9237  acc: 0.2089
#   Epoch 15 | Batch 200/1322 | loss: 2.9211  acc: 0.2093
#   Epoch 15 | Batch 300/1322 | loss: 2.9185  acc: 0.2097
#   Epoch 15 | Batch 400/1322 | loss: 2.9164  acc: 0.2101
#   Epoch 15 | Batch 500/1322 | loss: 2.9139  acc: 0.2105
#   Epoch 15 | Batch 600/1322 | loss: 2.9112  acc: 0.2112
#   Epoch 15 | Batch 700/1322 | loss: 2.9085  acc: 0.2116
#   Epoch 15 | Batch 800/1322 | loss: 2.9059  acc: 0.2121
#   Epoch 15 | Batch 900/1322 | loss: 2.9032  acc: 0.2128
#   Epoch 15 | Batch 1000/1322 | loss: 2.9008  acc: 0.2133
#   Epoch 15 | Batch 1100/1322 | loss: 2.8976  acc: 0.2140
#   Epoch 15 | Batch 1200/1322 | loss: 2.8952  acc: 0.2145
#   Epoch 15 | Batch 1300/1322 | loss: 2.8924  acc: 0.2150
# Epoch 15/20 | train_loss: 2.9093  train_acc: 0.2116 | val_loss: 2.8899  val_acc: 0.2156 | 380.5s
#   💾 Saved best model (val_loss: 2.8899)
#   Epoch 16 | Batch 100/1322 | loss: 2.8866  acc: 0.2162
#   Epoch 16 | Batch 200/1322 | loss: 2.8840  acc: 0.2168
#   Epoch 16 | Batch 300/1322 | loss: 2.8808  acc: 0.2176
#   Epoch 16 | Batch 400/1322 | loss: 2.8777  acc: 0.2181
#   Epoch 16 | Batch 500/1322 | loss: 2.8755  acc: 0.2185
#   Epoch 16 | Batch 600/1322 | loss: 2.8731  acc: 0.2192
#   Epoch 16 | Batch 700/1322 | loss: 2.8706  acc: 0.2197
#   Epoch 16 | Batch 800/1322 | loss: 2.8682  acc: 0.2203
#   Epoch 16 | Batch 900/1322 | loss: 2.8658  acc: 0.2207
#   Epoch 16 | Batch 1000/1322 | loss: 2.8634  acc: 0.2211
#   Epoch 16 | Batch 1100/1322 | loss: 2.8609  acc: 0.2216
#   Epoch 16 | Batch 1200/1322 | loss: 2.8582  acc: 0.2222
#   Epoch 16 | Batch 1300/1322 | loss: 2.8561  acc: 0.2227
# Epoch 16/20 | train_loss: 2.8719  train_acc: 0.2194 | val_loss: 2.8536  val_acc: 0.2234 | 368.0s
#   💾 Saved best model (val_loss: 2.8536)
#   Epoch 17 | Batch 100/1322 | loss: 2.8502  acc: 0.2241
#   Epoch 17 | Batch 200/1322 | loss: 2.8473  acc: 0.2248
#   Epoch 17 | Batch 300/1322 | loss: 2.8450  acc: 0.2254
#   Epoch 17 | Batch 400/1322 | loss: 2.8425  acc: 0.2258
#   Epoch 17 | Batch 500/1322 | loss: 2.8398  acc: 0.2265
#   Epoch 17 | Batch 600/1322 | loss: 2.8373  acc: 0.2269
#   Epoch 17 | Batch 700/1322 | loss: 2.8349  acc: 0.2274
#   Epoch 17 | Batch 800/1322 | loss: 2.8322  acc: 0.2281
#   Epoch 17 | Batch 900/1322 | loss: 2.8295  acc: 0.2288
#   Epoch 17 | Batch 1000/1322 | loss: 2.8269  acc: 0.2293
#   Epoch 17 | Batch 1100/1322 | loss: 2.8241  acc: 0.2298
#   Epoch 17 | Batch 1200/1322 | loss: 2.8214  acc: 0.2306
#   Epoch 17 | Batch 1300/1322 | loss: 2.8190  acc: 0.2311
# Epoch 17/20 | train_loss: 2.8356  train_acc: 0.2274 | val_loss: 2.8163  val_acc: 0.2317 | 356.3s
#   💾 Saved best model (val_loss: 2.8163)
#   Epoch 18 | Batch 100/1322 | loss: 2.8135  acc: 0.2322
#   Epoch 18 | Batch 200/1322 | loss: 2.8111  acc: 0.2328
#   Epoch 18 | Batch 300/1322 | loss: 2.8081  acc: 0.2335
#   Epoch 18 | Batch 400/1322 | loss: 2.8056  acc: 0.2341
#   Epoch 18 | Batch 500/1322 | loss: 2.8033  acc: 0.2345
#   Epoch 18 | Batch 600/1322 | loss: 2.8010  acc: 0.2350
#   Epoch 18 | Batch 700/1322 | loss: 2.7983  acc: 0.2357
#   Epoch 18 | Batch 800/1322 | loss: 2.7956  acc: 0.2365
#   Epoch 18 | Batch 900/1322 | loss: 2.7930  acc: 0.2370
#   Epoch 18 | Batch 1000/1322 | loss: 2.7902  acc: 0.2378
#   Epoch 18 | Batch 1100/1322 | loss: 2.7878  acc: 0.2383
#   Epoch 18 | Batch 1200/1322 | loss: 2.7854  acc: 0.2389
#   Epoch 18 | Batch 1300/1322 | loss: 2.7830  acc: 0.2394
# Epoch 18/20 | train_loss: 2.7991  train_acc: 0.2356 | val_loss: 2.7811  val_acc: 0.2398 | 347.4s
#   💾 Saved best model (val_loss: 2.7811)
#   Epoch 19 | Batch 100/1322 | loss: 2.7785  acc: 0.2403
#   Epoch 19 | Batch 200/1322 | loss: 2.7756  acc: 0.2410
#   Epoch 19 | Batch 300/1322 | loss: 2.7729  acc: 0.2417
#   Epoch 19 | Batch 400/1322 | loss: 2.7705  acc: 0.2423
#   Epoch 19 | Batch 500/1322 | loss: 2.7673  acc: 0.2430
#   Epoch 19 | Batch 600/1322 | loss: 2.7649  acc: 0.2435
#   Epoch 19 | Batch 700/1322 | loss: 2.7630  acc: 0.2440
#   Epoch 19 | Batch 800/1322 | loss: 2.7607  acc: 0.2444
#   Epoch 19 | Batch 900/1322 | loss: 2.7580  acc: 0.2451
#   Epoch 19 | Batch 1000/1322 | loss: 2.7561  acc: 0.2455
#   Epoch 19 | Batch 1100/1322 | loss: 2.7537  acc: 0.2460
#   Epoch 19 | Batch 1200/1322 | loss: 2.7511  acc: 0.2466
#   Epoch 19 | Batch 1300/1322 | loss: 2.7484  acc: 0.2472
# Epoch 19/20 | train_loss: 2.7641  train_acc: 0.2437 | val_loss: 2.7461  val_acc: 0.2476 | 347.9s
#   💾 Saved best model (val_loss: 2.7461)
#   Epoch 20 | Batch 100/1322 | loss: 2.7428  acc: 0.2483
#   Epoch 20 | Batch 200/1322 | loss: 2.7399  acc: 0.2489
#   Epoch 20 | Batch 300/1322 | loss: 2.7373  acc: 0.2495
#   Epoch 20 | Batch 400/1322 | loss: 2.7350  acc: 0.2500
#   Epoch 20 | Batch 500/1322 | loss: 2.7330  acc: 0.2504
#   Epoch 20 | Batch 600/1322 | loss: 2.7307  acc: 0.2510
#   Epoch 20 | Batch 700/1322 | loss: 2.7282  acc: 0.2515
#   Epoch 20 | Batch 800/1322 | loss: 2.7257  acc: 0.2522
#   Epoch 20 | Batch 900/1322 | loss: 2.7230  acc: 0.2529
#   Epoch 20 | Batch 1000/1322 | loss: 2.7206  acc: 0.2535
#   Epoch 20 | Batch 1100/1322 | loss: 2.7184  acc: 0.2539
#   Epoch 20 | Batch 1200/1322 | loss: 2.7164  acc: 0.2545
#   Epoch 20 | Batch 1300/1322 | loss: 2.7141  acc: 0.2550
# Epoch 20/20 | train_loss: 2.7290  train_acc: 0.2514 | val_loss: 2.7119  val_acc: 0.2555 | 356.7s
#   💾 Saved best model (val_loss: 2.7119)
#
# ✅ Training complete. Best val_loss: 2.7119
