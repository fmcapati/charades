# %% [markdown]
# ## M1_CNNImproved_GRU
#
# Improved CNN backbone (32→64→128 filters vs 16→32→64 in M1) paired with a GRU. Same 3-block structure — doubled filter capacity per layer for a controlled comparison.

# %%
import torch, gc
gc.collect()
torch.cuda.empty_cache()
print(f"GPU free: {(torch.cuda.get_device_properties(0).total_memory - torch.cuda.memory_reserved(0))/1024**3:.2f} GiB")
# Out:
# GPU free: 10.90 GiB

# %%
import os, gc, time, csv, cv2
os.environ["KERAS_BACKEND"]              = "torch"
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"
os.environ["PYTORCH_CUDA_ALLOC_CONF"]    = "expandable_segments:True"

import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from pathlib import Path
import keras
from keras import layers, optimizers

# ── Reproducibility ───────────────────────────────────────────────────────────
SEED = 42
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ── Paths ─────────────────────────────────────────────────────────────────────
DATA_DIR   = Path("/home2/msds2026/fcapati/ml3_2026/Projects/Final_Project/data")
FRAMES_DIR = DATA_DIR / "UCF50_frames"
DATASET_DIR = DATA_DIR / "UCF50"

# ── Config ────────────────────────────────────────────────────────────────────
IMG_HEIGHT      = 64
IMG_WIDTH       = 64
SEQUENCE_LENGTH = 16
BATCH_SIZE      = 4
EPOCHS          = 20
LEARNING_RATE   = 1e-4
NUM_CLASSES     = 50

# ── Class mapping ─────────────────────────────────────────────────────────────
CLASS_NAMES_SORTED = sorted([d.name for d in DATASET_DIR.iterdir() if d.is_dir()])
class_to_idx       = {cls: idx for idx, cls in enumerate(CLASS_NAMES_SORTED)}
idx_to_class       = {idx: cls for cls, idx in class_to_idx.items()}

print(f"✅ Keras backend : {keras.backend.backend()}")
print(f"✅ Device        : {DEVICE}")
print(f"✅ Classes       : {len(class_to_idx)}")
print(f"✅ Frames dir    : {FRAMES_DIR.exists()}")
# Out:
# ✅ Keras backend : torch
# ✅ Device        : cuda
# ✅ Classes       : 50
# ✅ Frames dir    : True

# %%
class PreextractedDataset(Dataset):
    """Loads pre-extracted .npy frame arrays — fast, no video I/O during training."""
    def __init__(self, frames_dir, split, class_to_idx):
        self.samples = []
        for class_dir in sorted((Path(frames_dir) / split).iterdir()):
            if not class_dir.is_dir():
                continue
            label = class_to_idx[class_dir.name]
            for npy_path in sorted(class_dir.glob("*.npy")):
                self.samples.append((str(npy_path), label))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        npy_path, label = self.samples[idx]
        frames = np.load(npy_path)  # (16, 112, 112, 3)
        
        # Resize to target resolution if needed
        if frames.shape[1] != IMG_HEIGHT:
            frames = np.stack([
                cv2.resize(f, (IMG_WIDTH, IMG_HEIGHT)) for f in frames
            ])
        
        frames = torch.tensor(frames).permute(3, 0, 1, 2).float()
        return frames, torch.tensor(label, dtype=torch.long)


train_dataset = PreextractedDataset(FRAMES_DIR, "train", class_to_idx)
val_dataset   = PreextractedDataset(FRAMES_DIR, "val",   class_to_idx)
test_dataset  = PreextractedDataset(FRAMES_DIR, "test",  class_to_idx)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,
                          num_workers=0, pin_memory=False)
val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=0, pin_memory=False)
test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=0, pin_memory=False)

print(f"✅ Train : {len(train_dataset):,} videos → {len(train_loader)} steps/epoch")
print(f"✅ Val   : {len(val_dataset):,} videos → {len(val_loader)} steps/epoch")
print(f"✅ Test  : {len(test_dataset):,} videos → {len(test_loader)} steps/epoch")

# ── Quick shape check ─────────────────────────────────────────────────────────
sample_frames, sample_labels = next(iter(train_loader))
print(f"\nBatch frames : {sample_frames.shape}  → (B, C, T, H, W)")
print(f"Batch labels : {sample_labels.shape}  dtype={sample_labels.dtype}")
# Out:
# ✅ Train : 5,288 videos → 1322 steps/epoch
# ✅ Val   : 640 videos → 160 steps/epoch
# ✅ Test  : 698 videos → 175 steps/epoch
#
# Batch frames : torch.Size([4, 3, 16, 64, 64])  → (B, C, T, H, W)
# Batch labels : torch.Size([4])  dtype=torch.int64

# %%
def train_model_keras(model, model_name, train_loader, val_loader, epochs=EPOCHS):
    """
    Training loop for Keras (torch backend) with PyTorch DataLoader.
    Features: per-batch cache clearing, early stopping (patience=5),
    checkpointing, CSV history logging, flush=True for real-time output.
    """
    gc.collect()
    torch.cuda.empty_cache()
    print(f"GPU memory reserved: {torch.cuda.memory_reserved()/1024**3:.2f} GiB", flush=True)

    model.compile(
        optimizer = optimizers.Adam(learning_rate=LEARNING_RATE),
        loss      = "sparse_categorical_crossentropy",
        metrics   = ["accuracy"]
    )

    best_val_loss  = float("inf")
    patience_count = 0
    patience       = 5
    history        = []

    print(f"\n{'='*60}", flush=True)
    print(f"Training: {model_name}", flush=True)
    print(f"{'='*60}", flush=True)

    for epoch in range(1, epochs + 1):
        t0 = time.time()

        # ── Training ──────────────────────────────────────────────────────────
        train_losses, train_accs = [], []
        for batch_idx, (frames, labels) in enumerate(train_loader):
            frames_np = frames.permute(0, 2, 3, 4, 1).numpy()
            labels_np = labels.numpy()
            metrics   = model.train_on_batch(frames_np, labels_np)
            train_losses.append(metrics[0])
            train_accs.append(metrics[1])

            # Clear cache every 50 batches to prevent fragmentation
            if (batch_idx + 1) % 50 == 0:
                torch.cuda.empty_cache()

            if (batch_idx + 1) % 100 == 0:
                print(f"  Epoch {epoch} | Batch {batch_idx+1}/{len(train_loader)} | "
                      f"loss: {metrics[0]:.4f}  acc: {metrics[1]:.4f}", flush=True)

        # ── Validation ────────────────────────────────────────────────────────
        val_losses, val_accs = [], []
        for frames, labels in val_loader:
            frames_np = frames.permute(0, 2, 3, 4, 1).numpy()
            labels_np = labels.numpy()
            metrics   = model.test_on_batch(frames_np, labels_np)
            val_losses.append(metrics[0])
            val_accs.append(metrics[1])

        train_loss = sum(train_losses) / len(train_losses)
        train_acc  = sum(train_accs)  / len(train_accs)
        val_loss   = sum(val_losses)  / len(val_losses)
        val_acc    = sum(val_accs)    / len(val_accs)
        elapsed    = time.time() - t0

        history.append({
            "epoch": epoch, "train_loss": train_loss, "train_acc": train_acc,
            "val_loss": val_loss, "val_acc": val_acc
        })

        print(f"Epoch {epoch:02d}/{epochs} | "
              f"train_loss: {train_loss:.4f}  train_acc: {train_acc:.4f} | "
              f"val_loss: {val_loss:.4f}  val_acc: {val_acc:.4f} | "
              f"{elapsed:.1f}s", flush=True)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            model.save(f"best_{model_name}.keras")
            print(f"  💾 Saved best model (val_loss: {best_val_loss:.4f})", flush=True)
            patience_count = 0
        else:
            patience_count += 1
            print(f"  ⏳ No improvement ({patience_count}/{patience})", flush=True)
            if patience_count >= patience:
                print(f"\nEarly stopping at epoch {epoch}.", flush=True)
                break

    # Save history to CSV
    with open(f"history_{model_name}.csv", "w", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=history[0].keys())
        writer.writeheader()
        writer.writerows(history)

    print(f"\n✅ Training complete. Best val_loss: {best_val_loss:.4f}", flush=True)
    return model, history

print("✅ Training loop ready")
# Out:
# ✅ Training loop ready

# %% [markdown]
# ### Model Definition
#
# Identical to M1 except CNN filters are doubled (32→64→128). This tests whether increased spatial feature capacity improves GRU-based temporal modeling without architectural changes.

# %%
# ── M1_CNNImproved_GRU ──────────────────────────────────────────────────────
# Increased CNN filters from 16→32→64 to 32→64→128.
# Same 3-block structure as baseline — more capacity per layer, not more layers.
# All other hyperparameters kept identical for a controlled comparison.

inputs = keras.Input(shape=(SEQUENCE_LENGTH, IMG_HEIGHT, IMG_WIDTH, 3))

# ── TimeDistributed CNN Block (32→64→128 vs 16→32→64 in baseline) ────────────
x = layers.TimeDistributed(layers.Conv2D(32, (3,3), activation="relu", padding="same"))(inputs)
x = layers.TimeDistributed(layers.MaxPooling2D((2,2)))(x)

x = layers.TimeDistributed(layers.Conv2D(64, (3,3), activation="relu", padding="same"))(x)
x = layers.TimeDistributed(layers.MaxPooling2D((2,2)))(x)

x = layers.TimeDistributed(layers.Conv2D(128, (3,3), activation="relu", padding="same"))(x)
x = layers.TimeDistributed(layers.GlobalAveragePooling2D())(x)

# ── GRU Temporal Block ──────────────────────────────────────────────
# GRU: update + reset gates, fewer params than LSTM.
x = layers.GRU(128, return_sequences=False)(x)
x = layers.Dense(256, activation="relu")(x)
outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)

model = keras.Model(inputs, outputs, name="M1_CNNImproved_GRU")

total_params = sum(int(np.prod(w.shape)) for w in model.weights)
print(f"Model     : M1_CNNImproved_GRU")
print(f"Params    : {total_params:,}")
model.summary()
# Out:
# Model     : M1_CNNImproved_GRU
# Params    : 238,194
# Model: "M1_CNNImproved_GRU"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 16, 64, 64, 3)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 16, 64, 64, 32) │           896 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 16, 32, 32, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 16, 32, 32, 64) │        18,496 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_3              │ (None, 16, 16, 16, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_4              │ (None, 16, 16, 16,     │        73,856 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_5              │ (None, 16, 128)        │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 128)            │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 50)             │        12,850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 238,194 (930.45 KB)
#  Trainable params: 238,194 (930.45 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Training

# %%
# ── Train M1_CNNImproved_GRU ────────────────────────────────────────────────────────
model, history = train_model_keras(model, "M1_CNNImproved_GRU", train_loader, val_loader)
# Out:
# GPU memory reserved: 0.00 GiB
#
# ============================================================
# Training: M1_CNNImproved_GRU
# ============================================================
# /home/msds2026/fcapati/.conda/envs/msds2026-ml3-cnn/lib/python3.11/site-packages/keras/src/backend/torch/rnn.py:853: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1479.)
#   outputs, h_n = torch._VF.gru(
#   Epoch 1 | Batch 100/1322 | loss: 3.9111  acc: 0.0275
#   Epoch 1 | Batch 200/1322 | loss: 3.9088  acc: 0.0312
#   Epoch 1 | Batch 300/1322 | loss: 3.9076  acc: 0.0300
#   Epoch 1 | Batch 400/1322 | loss: 3.9055  acc: 0.0306
#   Epoch 1 | Batch 500/1322 | loss: 3.9039  acc: 0.0290
#   Epoch 1 | Batch 600/1322 | loss: 3.9024  acc: 0.0279
#   Epoch 1 | Batch 700/1322 | loss: 3.8950  acc: 0.0321
#   Epoch 1 | Batch 800/1322 | loss: 3.8832  acc: 0.0356
#   Epoch 1 | Batch 900/1322 | loss: 3.8679  acc: 0.0389
#   Epoch 1 | Batch 1000/1322 | loss: 3.8532  acc: 0.0388
#   Epoch 1 | Batch 1100/1322 | loss: 3.8385  acc: 0.0405
#   Epoch 1 | Batch 1200/1322 | loss: 3.8173  acc: 0.0419
#   Epoch 1 | Batch 1300/1322 | loss: 3.8010  acc: 0.0433
# Epoch 01/20 | train_loss: 3.8796  train_acc: 0.0342 | val_loss: 3.7738  val_acc: 0.0477 | 313.8s
#   💾 Saved best model (val_loss: 3.7738)
#   Epoch 2 | Batch 100/1322 | loss: 3.7497  acc: 0.0506
#   Epoch 2 | Batch 200/1322 | loss: 3.7344  acc: 0.0525
#   Epoch 2 | Batch 300/1322 | loss: 3.7211  acc: 0.0553
#   Epoch 2 | Batch 400/1322 | loss: 3.7092  acc: 0.0555
#   Epoch 2 | Batch 500/1322 | loss: 3.6953  acc: 0.0576
#   Epoch 2 | Batch 600/1322 | loss: 3.6841  acc: 0.0587
#   Epoch 2 | Batch 700/1322 | loss: 3.6677  acc: 0.0600
#   Epoch 2 | Batch 800/1322 | loss: 3.6576  acc: 0.0623
#   Epoch 2 | Batch 900/1322 | loss: 3.6483  acc: 0.0641
#   Epoch 2 | Batch 1000/1322 | loss: 3.6354  acc: 0.0663
#   Epoch 2 | Batch 1100/1322 | loss: 3.6240  acc: 0.0686
#   Epoch 2 | Batch 1200/1322 | loss: 3.6172  acc: 0.0694
#   Epoch 2 | Batch 1300/1322 | loss: 3.6090  acc: 0.0708
# Epoch 02/20 | train_loss: 3.6780  train_acc: 0.0603 | val_loss: 3.5964  val_acc: 0.0753 | 335.4s
#   💾 Saved best model (val_loss: 3.5964)
#   Epoch 3 | Batch 100/1322 | loss: 3.5840  acc: 0.0774
#   Epoch 3 | Batch 200/1322 | loss: 3.5763  acc: 0.0784
#   Epoch 3 | Batch 300/1322 | loss: 3.5688  acc: 0.0798
#   Epoch 3 | Batch 400/1322 | loss: 3.5605  acc: 0.0809
#   Epoch 3 | Batch 500/1322 | loss: 3.5523  acc: 0.0821
#   Epoch 3 | Batch 600/1322 | loss: 3.5440  acc: 0.0836
#   Epoch 3 | Batch 700/1322 | loss: 3.5394  acc: 0.0850
#   Epoch 3 | Batch 800/1322 | loss: 3.5329  acc: 0.0857
#   Epoch 3 | Batch 900/1322 | loss: 3.5272  acc: 0.0868
#   Epoch 3 | Batch 1000/1322 | loss: 3.5223  acc: 0.0879
#   Epoch 3 | Batch 1100/1322 | loss: 3.5172  acc: 0.0885
#   Epoch 3 | Batch 1200/1322 | loss: 3.5107  acc: 0.0897
#   Epoch 3 | Batch 1300/1322 | loss: 3.5052  acc: 0.0903
# Epoch 03/20 | train_loss: 3.5442  train_acc: 0.0838 | val_loss: 3.4975  val_acc: 0.0927 | 326.5s
#   💾 Saved best model (val_loss: 3.4975)
#   Epoch 4 | Batch 100/1322 | loss: 3.4920  acc: 0.0937
#   Epoch 4 | Batch 200/1322 | loss: 3.4878  acc: 0.0943
#   Epoch 4 | Batch 300/1322 | loss: 3.4826  acc: 0.0957
#   Epoch 4 | Batch 400/1322 | loss: 3.4767  acc: 0.0969
#   Epoch 4 | Batch 500/1322 | loss: 3.4706  acc: 0.0979
#   Epoch 4 | Batch 600/1322 | loss: 3.4651  acc: 0.0987
#   Epoch 4 | Batch 700/1322 | loss: 3.4621  acc: 0.0988
#   Epoch 4 | Batch 800/1322 | loss: 3.4587  acc: 0.0996
#   Epoch 4 | Batch 900/1322 | loss: 3.4543  acc: 0.1006
#   Epoch 4 | Batch 1000/1322 | loss: 3.4495  acc: 0.1010
#   Epoch 4 | Batch 1100/1322 | loss: 3.4457  acc: 0.1013
#   Epoch 4 | Batch 1200/1322 | loss: 3.4417  acc: 0.1018
#   Epoch 4 | Batch 1300/1322 | loss: 3.4368  acc: 0.1032
# Epoch 04/20 | train_loss: 3.4651  train_acc: 0.0984 | val_loss: 3.4311  val_acc: 0.1048 | 336.7s
#   💾 Saved best model (val_loss: 3.4311)
#   Epoch 5 | Batch 100/1322 | loss: 3.4251  acc: 0.1055
#   Epoch 5 | Batch 200/1322 | loss: 3.4212  acc: 0.1059
#   Epoch 5 | Batch 300/1322 | loss: 3.4187  acc: 0.1059
#   Epoch 5 | Batch 400/1322 | loss: 3.4158  acc: 0.1061
#   Epoch 5 | Batch 500/1322 | loss: 3.4108  acc: 0.1070
#   Epoch 5 | Batch 600/1322 | loss: 3.4074  acc: 0.1074
#   Epoch 5 | Batch 700/1322 | loss: 3.4034  acc: 0.1084
#   Epoch 5 | Batch 800/1322 | loss: 3.4000  acc: 0.1090
#   Epoch 5 | Batch 900/1322 | loss: 3.3971  acc: 0.1094
#   Epoch 5 | Batch 1000/1322 | loss: 3.3928  acc: 0.1101
#   Epoch 5 | Batch 1100/1322 | loss: 3.3897  acc: 0.1107
#   Epoch 5 | Batch 1200/1322 | loss: 3.3869  acc: 0.1109
#   Epoch 5 | Batch 1300/1322 | loss: 3.3838  acc: 0.1120
# Epoch 05/20 | train_loss: 3.4054  train_acc: 0.1081 | val_loss: 3.3791  val_acc: 0.1132 | 327.8s
#   💾 Saved best model (val_loss: 3.3791)
#   Epoch 6 | Batch 100/1322 | loss: 3.3749  acc: 0.1139
#   Epoch 6 | Batch 200/1322 | loss: 3.3720  acc: 0.1144
#   Epoch 6 | Batch 300/1322 | loss: 3.3678  acc: 0.1151
#   Epoch 6 | Batch 400/1322 | loss: 3.3657  acc: 0.1154
#   Epoch 6 | Batch 500/1322 | loss: 3.3619  acc: 0.1160
#   Epoch 6 | Batch 600/1322 | loss: 3.3584  acc: 0.1166
#   Epoch 6 | Batch 700/1322 | loss: 3.3552  acc: 0.1172
#   Epoch 6 | Batch 800/1322 | loss: 3.3528  acc: 0.1176
#   Epoch 6 | Batch 900/1322 | loss: 3.3498  acc: 0.1183
#   Epoch 6 | Batch 1000/1322 | loss: 3.3467  acc: 0.1189
#   Epoch 6 | Batch 1100/1322 | loss: 3.3442  acc: 0.1190
#   Epoch 6 | Batch 1200/1322 | loss: 3.3406  acc: 0.1199
#   Epoch 6 | Batch 1300/1322 | loss: 3.3382  acc: 0.1203
# Epoch 06/20 | train_loss: 3.3572  train_acc: 0.1169 | val_loss: 3.3366  val_acc: 0.1210 | 323.2s
#   💾 Saved best model (val_loss: 3.3366)
#   Epoch 7 | Batch 100/1322 | loss: 3.3347  acc: 0.1214
#   Epoch 7 | Batch 200/1322 | loss: 3.3306  acc: 0.1220
#   Epoch 7 | Batch 300/1322 | loss: 3.3268  acc: 0.1226
#   Epoch 7 | Batch 400/1322 | loss: 3.3243  acc: 0.1233
#   Epoch 7 | Batch 500/1322 | loss: 3.3212  acc: 0.1239
#   Epoch 7 | Batch 600/1322 | loss: 3.3184  acc: 0.1244
#   Epoch 7 | Batch 700/1322 | loss: 3.3154  acc: 0.1252
#   Epoch 7 | Batch 800/1322 | loss: 3.3127  acc: 0.1257
#   Epoch 7 | Batch 900/1322 | loss: 3.3097  acc: 0.1266
#   Epoch 7 | Batch 1000/1322 | loss: 3.3074  acc: 0.1272
#   Epoch 7 | Batch 1100/1322 | loss: 3.3057  acc: 0.1274
#   Epoch 7 | Batch 1200/1322 | loss: 3.3026  acc: 0.1279
#   Epoch 7 | Batch 1300/1322 | loss: 3.3001  acc: 0.1283
# Epoch 07/20 | train_loss: 3.3172  train_acc: 0.1249 | val_loss: 3.2964  val_acc: 0.1292 | 316.8s
#   💾 Saved best model (val_loss: 3.2964)
#   Epoch 8 | Batch 100/1322 | loss: 3.2929  acc: 0.1294
#   Epoch 8 | Batch 200/1322 | loss: 3.2906  acc: 0.1299
#   Epoch 8 | Batch 300/1322 | loss: 3.2878  acc: 0.1305
#   Epoch 8 | Batch 400/1322 | loss: 3.2850  acc: 0.1311
#   Epoch 8 | Batch 500/1322 | loss: 3.2830  acc: 0.1316
#   Epoch 8 | Batch 600/1322 | loss: 3.2796  acc: 0.1321
#   Epoch 8 | Batch 700/1322 | loss: 3.2770  acc: 0.1328
#   Epoch 8 | Batch 800/1322 | loss: 3.2741  acc: 0.1334
#   Epoch 8 | Batch 900/1322 | loss: 3.2716  acc: 0.1338
#   Epoch 8 | Batch 1000/1322 | loss: 3.2696  acc: 0.1341
#   Epoch 8 | Batch 1100/1322 | loss: 3.2669  acc: 0.1347
#   Epoch 8 | Batch 1200/1322 | loss: 3.2647  acc: 0.1351
#   Epoch 8 | Batch 1300/1322 | loss: 3.2614  acc: 0.1360
# Epoch 08/20 | train_loss: 3.2783  train_acc: 0.1324 | val_loss: 3.2585  val_acc: 0.1368 | 325.7s
#   💾 Saved best model (val_loss: 3.2585)
#   Epoch 9 | Batch 100/1322 | loss: 3.2560  acc: 0.1373
#   Epoch 9 | Batch 200/1322 | loss: 3.2529  acc: 0.1379
#   Epoch 9 | Batch 300/1322 | loss: 3.2496  acc: 0.1387
#   Epoch 9 | Batch 400/1322 | loss: 3.2482  acc: 0.1389
#   Epoch 9 | Batch 500/1322 | loss: 3.2463  acc: 0.1393
#   Epoch 9 | Batch 600/1322 | loss: 3.2436  acc: 0.1397
#   Epoch 9 | Batch 700/1322 | loss: 3.2405  acc: 0.1404
#   Epoch 9 | Batch 800/1322 | loss: 3.2376  acc: 0.1412
#   Epoch 9 | Batch 900/1322 | loss: 3.2355  acc: 0.1414
#   Epoch 9 | Batch 1000/1322 | loss: 3.2333  acc: 0.1419
#   Epoch 9 | Batch 1100/1322 | loss: 3.2309  acc: 0.1423
#   Epoch 9 | Batch 1200/1322 | loss: 3.2278  acc: 0.1427
#   Epoch 9 | Batch 1300/1322 | loss: 3.2249  acc: 0.1433
# Epoch 09/20 | train_loss: 3.2415  train_acc: 0.1402 | val_loss: 3.2213  val_acc: 0.1442 | 313.8s
#   💾 Saved best model (val_loss: 3.2213)
#   Epoch 10 | Batch 100/1322 | loss: 3.2187  acc: 0.1446
#   Epoch 10 | Batch 200/1322 | loss: 3.2165  acc: 0.1449
#   Epoch 10 | Batch 300/1322 | loss: 3.2136  acc: 0.1453
#   Epoch 10 | Batch 400/1322 | loss: 3.2112  acc: 0.1458
#   Epoch 10 | Batch 500/1322 | loss: 3.2085  acc: 0.1463
#   Epoch 10 | Batch 600/1322 | loss: 3.2058  acc: 0.1468
#   Epoch 10 | Batch 700/1322 | loss: 3.2038  acc: 0.1473
#   Epoch 10 | Batch 800/1322 | loss: 3.2017  acc: 0.1478
#   Epoch 10 | Batch 900/1322 | loss: 3.1990  acc: 0.1484
#   Epoch 10 | Batch 1000/1322 | loss: 3.1965  acc: 0.1488
#   Epoch 10 | Batch 1100/1322 | loss: 3.1940  acc: 0.1493
#   Epoch 10 | Batch 1200/1322 | loss: 3.1916  acc: 0.1499
#   Epoch 10 | Batch 1300/1322 | loss: 3.1898  acc: 0.1504
# Epoch 10/20 | train_loss: 3.2048  train_acc: 0.1472 | val_loss: 3.1871  val_acc: 0.1511 | 308.9s
#   💾 Saved best model (val_loss: 3.1871)
#   Epoch 11 | Batch 100/1322 | loss: 3.1849  acc: 0.1513
#   Epoch 11 | Batch 200/1322 | loss: 3.1822  acc: 0.1519
#   Epoch 11 | Batch 300/1322 | loss: 3.1800  acc: 0.1523
#   Epoch 11 | Batch 400/1322 | loss: 3.1775  acc: 0.1529
#   Epoch 11 | Batch 500/1322 | loss: 3.1752  acc: 0.1534
#   Epoch 11 | Batch 600/1322 | loss: 3.1727  acc: 0.1538
#   Epoch 11 | Batch 700/1322 | loss: 3.1708  acc: 0.1541
#   Epoch 11 | Batch 800/1322 | loss: 3.1683  acc: 0.1546
#   Epoch 11 | Batch 900/1322 | loss: 3.1664  acc: 0.1550
#   Epoch 11 | Batch 1000/1322 | loss: 3.1634  acc: 0.1555
#   Epoch 11 | Batch 1100/1322 | loss: 3.1611  acc: 0.1560
#   Epoch 11 | Batch 1200/1322 | loss: 3.1587  acc: 0.1564
#   Epoch 11 | Batch 1300/1322 | loss: 3.1564  acc: 0.1568
#   Epoch 12 | Batch 400/1322 | loss: 3.1443  acc: 0.1593
#   Epoch 12 | Batch 500/1322 | loss: 3.1415  acc: 0.1598
#   Epoch 12 | Batch 600/1322 | loss: 3.1392  acc: 0.1602
#   Epoch 12 | Batch 700/1322 | loss: 3.1374  acc: 0.1606
#   Epoch 12 | Batch 800/1322 | loss: 3.1351  acc: 0.1610
#   Epoch 12 | Batch 900/1322 | loss: 3.1331  acc: 0.1615
#   Epoch 12 | Batch 1000/1322 | loss: 3.1310  acc: 0.1618
#   Epoch 12 | Batch 1100/1322 | loss: 3.1287  acc: 0.1620
#   Epoch 12 | Batch 1200/1322 | loss: 3.1265  acc: 0.1625
#   Epoch 12 | Batch 1300/1322 | loss: 3.1245  acc: 0.1630
# Epoch 12/20 | train_loss: 3.1382  train_acc: 0.1604 | val_loss: 3.1214  val_acc: 0.1638 | 305.3s
#   💾 Saved best model (val_loss: 3.1214)
#   Epoch 13 | Batch 100/1322 | loss: 3.1189  acc: 0.1641
#   Epoch 13 | Batch 200/1322 | loss: 3.1162  acc: 0.1646
#   Epoch 13 | Batch 300/1322 | loss: 3.1140  acc: 0.1651
#   Epoch 13 | Batch 400/1322 | loss: 3.1120  acc: 0.1654
#   Epoch 13 | Batch 500/1322 | loss: 3.1101  acc: 0.1657
#   Epoch 13 | Batch 600/1322 | loss: 3.1079  acc: 0.1662
#   Epoch 13 | Batch 700/1322 | loss: 3.1061  acc: 0.1665
#   Epoch 13 | Batch 800/1322 | loss: 3.1045  acc: 0.1668
#   Epoch 13 | Batch 900/1322 | loss: 3.1021  acc: 0.1673
#   Epoch 13 | Batch 1000/1322 | loss: 3.0994  acc: 0.1678
#   Epoch 13 | Batch 1100/1322 | loss: 3.0970  acc: 0.1684
#   Epoch 13 | Batch 1200/1322 | loss: 3.0950  acc: 0.1688
#   Epoch 13 | Batch 1300/1322 | loss: 3.0928  acc: 0.1692
# Epoch 13/20 | train_loss: 3.1066  train_acc: 0.1664 | val_loss: 3.0898  val_acc: 0.1701 | 304.0s
#   💾 Saved best model (val_loss: 3.0898)
#   Epoch 14 | Batch 100/1322 | loss: 3.0873  acc: 0.1707
#   Epoch 14 | Batch 200/1322 | loss: 3.0852  acc: 0.1712
#   Epoch 14 | Batch 800/1322 | loss: 3.0725  acc: 0.1740
#   Epoch 14 | Batch 900/1322 | loss: 3.0704  acc: 0.1745
#   Epoch 14 | Batch 1000/1322 | loss: 3.0680  acc: 0.1750
#   Epoch 14 | Batch 1100/1322 | loss: 3.0659  acc: 0.1755
#   Epoch 14 | Batch 1200/1322 | loss: 3.0637  acc: 0.1759
#   Epoch 14 | Batch 1300/1322 | loss: 3.0621  acc: 0.1761
# Epoch 14/20 | train_loss: 3.0754  train_acc: 0.1734 | val_loss: 3.0599  val_acc: 0.1767 | 306.2s
#   💾 Saved best model (val_loss: 3.0599)
#   Epoch 15 | Batch 100/1322 | loss: 3.0573  acc: 0.1769
#   Epoch 15 | Batch 200/1322 | loss: 3.0553  acc: 0.1773
#   Epoch 15 | Batch 300/1322 | loss: 3.0531  acc: 0.1777
#   Epoch 15 | Batch 400/1322 | loss: 3.0510  acc: 0.1780
#   Epoch 15 | Batch 500/1322 | loss: 3.0488  acc: 0.1785
#   Epoch 15 | Batch 600/1322 | loss: 3.0465  acc: 0.1789
#   Epoch 15 | Batch 700/1322 | loss: 3.0446  acc: 0.1793
#   Epoch 15 | Batch 800/1322 | loss: 3.0425  acc: 0.1797
#   Epoch 15 | Batch 900/1322 | loss: 3.0406  acc: 0.1802
#   Epoch 15 | Batch 1000/1322 | loss: 3.0384  acc: 0.1808
#   Epoch 15 | Batch 1100/1322 | loss: 3.0359  acc: 0.1814
#   Epoch 15 | Batch 1200/1322 | loss: 3.0340  acc: 0.1817
#   Epoch 15 | Batch 1300/1322 | loss: 3.0318  acc: 0.1821
# Epoch 15/20 | train_loss: 3.0455  train_acc: 0.1793 | val_loss: 3.0295  val_acc: 0.1828 | 308.2s
#   💾 Saved best model (val_loss: 3.0295)
#   Epoch 16 | Batch 100/1322 | loss: 3.0272  acc: 0.1832
#   Epoch 16 | Batch 200/1322 | loss: 3.0250  acc: 0.1836
#   Epoch 16 | Batch 300/1322 | loss: 3.0225  acc: 0.1842
#   Epoch 16 | Batch 400/1322 | loss: 3.0202  acc: 0.1848
#   Epoch 16 | Batch 500/1322 | loss: 3.0182  acc: 0.1853
#   Epoch 16 | Batch 600/1322 | loss: 3.0159  acc: 0.1856
#   Epoch 16 | Batch 700/1322 | loss: 3.0137  acc: 0.1861
#   Epoch 16 | Batch 800/1322 | loss: 3.0117  acc: 0.1865
#   Epoch 16 | Batch 900/1322 | loss: 3.0097  acc: 0.1868
#   Epoch 16 | Batch 1000/1322 | loss: 3.0080  acc: 0.1871
#   Epoch 16 | Batch 1100/1322 | loss: 3.0060  acc: 0.1875
#   Epoch 16 | Batch 1200/1322 | loss: 3.0037  acc: 0.1881
#   Epoch 16 | Batch 1300/1322 | loss: 3.0018  acc: 0.1885
# Epoch 16/20 | train_loss: 3.0149  train_acc: 0.1858 | val_loss: 2.9997  val_acc: 0.1891 | 309.1s
#   💾 Saved best model (val_loss: 2.9997)
#   Epoch 17 | Batch 100/1322 | loss: 2.9975  acc: 0.1897
#   Epoch 17 | Batch 200/1322 | loss: 2.9952  acc: 0.1903
#   Epoch 17 | Batch 300/1322 | loss: 2.9935  acc: 0.1907
#   Epoch 17 | Batch 400/1322 | loss: 2.9916  acc: 0.1911
#   Epoch 17 | Batch 500/1322 | loss: 2.9896  acc: 0.1914
#   Epoch 17 | Batch 600/1322 | loss: 2.9874  acc: 0.1918
#   Epoch 17 | Batch 700/1322 | loss: 2.9854  acc: 0.1921
#   Epoch 17 | Batch 800/1322 | loss: 2.9832  acc: 0.1927
#   Epoch 17 | Batch 900/1322 | loss: 2.9809  acc: 0.1933
#   Epoch 17 | Batch 1000/1322 | loss: 2.9787  acc: 0.1937
#   Epoch 17 | Batch 1100/1322 | loss: 2.9764  acc: 0.1943
#   Epoch 17 | Batch 1200/1322 | loss: 2.9741  acc: 0.1948
#   Epoch 17 | Batch 1300/1322 | loss: 2.9720  acc: 0.1953
# Epoch 17/20 | train_loss: 2.9859  train_acc: 0.1922 | val_loss: 2.9698  val_acc: 0.1960 | 330.2s
#   💾 Saved best model (val_loss: 2.9698)
#   Epoch 18 | Batch 100/1322 | loss: 2.9677  acc: 0.1965
#   Epoch 18 | Batch 200/1322 | loss: 2.9655  acc: 0.1971
#   Epoch 18 | Batch 300/1322 | loss: 2.9630  acc: 0.1976
#   Epoch 18 | Batch 400/1322 | loss: 2.9608  acc: 0.1982
#   Epoch 18 | Batch 500/1322 | loss: 2.9588  acc: 0.1985
#   Epoch 18 | Batch 600/1322 | loss: 2.9566  acc: 0.1991
#   Epoch 18 | Batch 700/1322 | loss: 2.9546  acc: 0.1995
#   Epoch 18 | Batch 800/1322 | loss: 2.9526  acc: 0.2000
#   Epoch 18 | Batch 900/1322 | loss: 2.9504  acc: 0.2005
#   Epoch 18 | Batch 1000/1322 | loss: 2.9480  acc: 0.2010
#   Epoch 18 | Batch 1100/1322 | loss: 2.9460  acc: 0.2015
#   Epoch 18 | Batch 1200/1322 | loss: 2.9442  acc: 0.2020
#   Epoch 18 | Batch 1300/1322 | loss: 2.9420  acc: 0.2024
# Epoch 18/20 | train_loss: 2.9554  train_acc: 0.1994 | val_loss: 2.9397  val_acc: 0.2029 | 311.5s
#   💾 Saved best model (val_loss: 2.9397)
#   Epoch 19 | Batch 100/1322 | loss: 2.9371  acc: 0.2035
#   Epoch 19 | Batch 200/1322 | loss: 2.9347  acc: 0.2040
#   Epoch 19 | Batch 300/1322 | loss: 2.9327  acc: 0.2045
#   Epoch 19 | Batch 400/1322 | loss: 2.9304  acc: 0.2050
#   Epoch 19 | Batch 500/1322 | loss: 2.9279  acc: 0.2056
#   Epoch 19 | Batch 600/1322 | loss: 2.9261  acc: 0.2062
#   Epoch 19 | Batch 700/1322 | loss: 2.9243  acc: 0.2066
#   Epoch 19 | Batch 800/1322 | loss: 2.9225  acc: 0.2070
#   Epoch 19 | Batch 900/1322 | loss: 2.9202  acc: 0.2075
#   Epoch 19 | Batch 1000/1322 | loss: 2.9183  acc: 0.2079
#   Epoch 19 | Batch 1100/1322 | loss: 2.9165  acc: 0.2083
#   Epoch 19 | Batch 1200/1322 | loss: 2.9143  acc: 0.2088
#   Epoch 19 | Batch 1300/1322 | loss: 2.9120  acc: 0.2094
# Epoch 19/20 | train_loss: 2.9252  train_acc: 0.2063 | val_loss: 2.9096  val_acc: 0.2100 | 306.8s
#   💾 Saved best model (val_loss: 2.9096)
#   Epoch 20 | Batch 100/1322 | loss: 2.9068  acc: 0.2107
#   Epoch 20 | Batch 200/1322 | loss: 2.9044  acc: 0.2112
#   Epoch 20 | Batch 300/1322 | loss: 2.9022  acc: 0.2117
#   Epoch 20 | Batch 400/1322 | loss: 2.9002  acc: 0.2121
#   Epoch 20 | Batch 500/1322 | loss: 2.8985  acc: 0.2124
#   Epoch 20 | Batch 600/1322 | loss: 2.8964  acc: 0.2130
#   Epoch 20 | Batch 700/1322 | loss: 2.8942  acc: 0.2135
#   Epoch 20 | Batch 800/1322 | loss: 2.8921  acc: 0.2140
#   Epoch 20 | Batch 900/1322 | loss: 2.8896  acc: 0.2146
#   Epoch 20 | Batch 1000/1322 | loss: 2.8877  acc: 0.2150
#   Epoch 20 | Batch 1100/1322 | loss: 2.8856  acc: 0.2156
#   Epoch 20 | Batch 1200/1322 | loss: 2.8836  acc: 0.2160
#   Epoch 20 | Batch 1300/1322 | loss: 2.8817  acc: 0.2165
# Epoch 20/20 | train_loss: 2.8949  train_acc: 0.2134 | val_loss: 2.8795  val_acc: 0.2170 | 310.7s
#   💾 Saved best model (val_loss: 2.8795)
#
# ✅ Training complete. Best val_loss: 2.8795
